# %% [markdown]
# <a href="https://colab.research.google.com/github/GryffindorafAviator/verifiable_ai_oracle_for_prediction_markets/blob/main/pm_fetch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import httpx
import json
import time

# %%
gamma_url = "https://gamma-api.polymarket.com"
gamma_markets_endpoint = gamma_url + "/markets"
gamma_events_endpoint = gamma_url + "/events"
gamma_tags_endpoint = gamma_url + "/tags"
limit = 20

# %%
def get_markets(querystring_params=None, local_file_path=None) -> list:
    if querystring_params is None:
        querystring_params = {}

    response = httpx.get(gamma_markets_endpoint, params=querystring_params)

    if response.status_code != 200:
        raise RuntimeError(f"API error: HTTP {response.status_code}")

    data = response.json()

    if local_file_path:
        with open(local_file_path, "w", encoding="utf-8") as f:
            json.dump(data, f, indent=2)

    return data

# %%
print(get_markets(querystring_params={"limit": limit}))
# Out:
# [{'id': '12', 'question': 'Will Joe Biden get Coronavirus before the election?', 'conditionId': '0xe3b423dfad8c22ff75c9899c4e8176f628cf4ad4caa00481764d320e7415f7a9', 'slug': 'will-joe-biden-get-coronavirus-before-the-election', 'twitterCardImage': 'https://polymarket-static.s3.us-east-2.amazonaws.com/polymarket-twitter-card.png', 'endDate': '2020-11-04T00:00:00Z', 'category': 'US-current-affairs', 'liquidity': '0', 'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-joe-biden-get-coronavirus-before-the-election-5a3d4c3b-0a73-419e-a686-be034d2c73ac.png', 'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-joe-biden-get-coronavirus-before-the-election-5a3d4c3b-0a73-419e-a686-be034d2c73ac.png', 'description': 'This is a market on if presidential candidate Joe Biden will test positive for COVID-19 before November 3rd, 2020. This will be defined as Joe publicly announcing - via any medium, including social media - that he has tested positive for COVID-19, or some variation of that statement. If it is in reference to antibodies, or he doesn’t publicly acknowledge it, the market will resolve to No.\nIn the event of ambiguity in terms of the market outcome, the market will be resolved at the sole discretion of the Markets Integrity Committee (MIC).', 'outcomes': '["Yes", "No"]', 'outcomePrices': '["0", "0"]', 'volume': '32257.445115', 'active': True, 'marketType': 'normal', 'closed': True, 'marketMakerAddress': '0x8BD6C3D7a57D650A1870dd338234f90051fe9918', 'updatedBy': 9, 'createdAt': '2020-10-02T16:10:01.467Z', 'updatedAt': '2024-04-23T00:49:51.620233Z', 'closedTime': '2020-11-02 16:31:01+00', 'mailchimpTag': '3917403', 'archived': False, 'restricted': False, 'volumeNum': 32257.45, 'liquidityNum': 0, 'endDateIso': '2020-11-04', 'hasReviewedDates': True, 'readyForCron': True, 'volume24hr': 0, 'volume1wk': 0, 'volume1mo': 0, 'volume1yr': 0, 'clobTokenIds': '["53135072462907880191400140706440867753044989936304433583131786753949599718775", "60869871469376321574904667328762911501870754872924453995477779862968218702336"]', 'fpmmLive': True, 'volume1wkAmm': 0, 'volume1moAmm': 0, 'volume1yrAmm': 0, 'volume1wkClob': 0, 'volume1moClob': 0, 'volume1yrClob': 0, 'events': [{'id': '4690', 'ticker': 'will-joe-biden-get-coronavirus-before-the-election', 'slug': 'will-joe-biden-get-coronavirus-before-the-election', 'title': 'Will Joe Biden get Coronavirus before the election?', 'description': 'This is a market on if presidential candidate Joe Biden will test positive for COVID-19 before November 3rd, 2020. This will be defined as Joe publicly announcing - via any medium, including social media - that he has tested positive for COVID-19, or some variation of that statement. If it is in reference to antibodies, or he doesn’t publicly acknowledge it, the market will resolve to No.\nIn the event of ambiguity in terms of the market outcome, the market will be resolved at the sole discretion of the Markets Integrity Committee (MIC).', 'startDate': '2020-10-02T00:00:00Z', 'creationDate': '2020-10-02T00:00:00Z', 'endDate': '2020-11-04T00:00:00Z', 'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-joe-biden-get-coronavirus-before-the-election-69e1dbcd-3cfe-4caf-b2af-c00e9ce7186f.png', 'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-joe-biden-get-coronavirus-before-the-election-69e1dbcd-3cfe-4caf-b2af-c00e9ce7186f.png', 'active': True, 'closed': True, 'archived': False, 'featured': False, 'restricted': False, 'liquidity': 0, 'volume': 32257.45, 'openInterest': 0, 'sortBy': 'ascending', 'category': 'US-current-affairs', 'published_at': '2022-07-27 14:41:12.085+00', 'createdAt': '2022-07-27T14:41:12.088Z', 'updatedAt': '2024-04-25T18:57:18.376169Z', 'competitive': 0, 'volume24hr': 0, 'volume1wk': 0, 'volume1mo': 0, 'volume1yr': 0, 'liquidityAmm': 0, 'liquidityClob': 0, 'commentCount': 0, 'cyom': False, 'closedTime': '2022-07-27T14:41:12.088Z', 'showAllOutcomes': False, 'showMarketImages': True, ' ...

# %%
def get_events(querystring_params=None, local_file_path=None) -> "list":
        if querystring_params is None:
          querystring_params = {}

        response = httpx.get(gamma_events_endpoint, params=querystring_params)

        if response.status_code != 200:
          raise RuntimeError(f"API error: HTTP {response.status_code}")

        data = response.json()

        if local_file_path:
            with open(local_file_path, "w", encoding="utf-8") as f:
                json.dump(data, f, indent=2)

        return data

# %%
print(get_events(querystring_params={"limit": limit}))
# Out:
# [{'id': '2890', 'ticker': 'nba-will-the-mavericks-beat-the-grizzlies-by-more-than-5pt5-points-in-their-december-4-matchup', 'slug': 'nba-will-the-mavericks-beat-the-grizzlies-by-more-than-5pt5-points-in-their-december-4-matchup', 'title': 'NBA: Will the Mavericks beat the Grizzlies by more than 5.5 points in their December 4 matchup?', 'description': 'In the upcoming NBA game, scheduled for December 4:\n\nIf the Dallas Mavericks win by over 5.5 points, the market will resolve to “Yes”.\n\nIf the Memphis Grizzlies lose by less than 5.5 points or win, the market will resolve “No.” \n\nIf the game is not completed by December 11, 2021, the market will resolve 50-50.', 'resolutionSource': 'https://www.nba.com/games', 'startDate': '2021-12-04T00:00:00Z', 'creationDate': '2021-12-04T00:00:00Z', 'endDate': '2021-12-04T00:00:00Z', 'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nba-will-the-mavericks-beat-the-grizzlies-by-more-than-55-points-in-their-december-4-matchup-543e7263-67da-4905-8732-cd3f220ae751.png', 'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nba-will-the-mavericks-beat-the-grizzlies-by-more-than-55-points-in-their-december-4-matchup-543e7263-67da-4905-8732-cd3f220ae751.png', 'active': True, 'closed': True, 'archived': False, 'new': False, 'featured': False, 'restricted': False, 'liquidity': 0, 'volume': 1335.05, 'openInterest': 0, 'sortBy': 'ascending', 'category': 'Sports', 'published_at': '2022-07-27 14:40:02.064+00', 'createdAt': '2022-07-27T14:40:02.074Z', 'updatedAt': '2024-04-25T18:49:06.075795Z', 'competitive': 0, 'volume24hr': 0, 'volume1wk': 0, 'volume1mo': 0, 'volume1yr': 0, 'liquidityAmm': 0, 'liquidityClob': 0, 'commentCount': 8125, 'markets': [{'id': '239826', 'question': 'NBA: Will the Mavericks beat the Grizzlies by more than 5.5 points in their December 4 matchup?', 'conditionId': '0x064d33e3f5703792aafa92bfb0ee10e08f461b1b34c02c1f02671892ede1609a', 'slug': 'nba-will-the-mavericks-beat-the-grizzlies-by-more-than-5pt5-points-in-their-december-4-matchup', 'resolutionSource': 'https://www.nba.com/games', 'endDate': '2021-12-04T00:00:00Z', 'category': 'Sports', 'liquidity': '50.000009', 'startDate': '2021-12-04T19:35:03.796Z', 'fee': '20000000000000000', 'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nba-will-the-mavericks-beat-the-grizzlies-by-more-than-55-points-in-their-december-4-matchup-aa2992d1-38df-404a-9190-49a909775014.png', 'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nba-will-the-mavericks-beat-the-grizzlies-by-more-than-55-points-in-their-december-4-matchup-aa2992d1-38df-404a-9190-49a909775014.png', 'description': 'In the upcoming NBA game, scheduled for December 4:\n\nIf the Dallas Mavericks win by over 5.5 points, the market will resolve to “Yes”.\n\nIf the Memphis Grizzlies lose by less than 5.5 points or win, the market will resolve “No.” \n\nIf the game is not completed by December 11, 2021, the market will resolve 50-50.', 'outcomes': '["Yes", "No"]', 'outcomePrices': '["0.0000004113679809846114013590098187297978", "0.9999995886320190153885986409901813"]', 'volume': '1335.045385', 'active': True, 'marketType': 'normal', 'closed': True, 'marketMakerAddress': '0x9c568Ce9a316e7CF9bCCA352b409dfDdCD9b2C08', 'updatedBy': 15, 'createdAt': '2021-12-04T10:33:13.541Z', 'updatedAt': '2024-04-24T23:35:51.063381Z', 'closedTime': '2021-12-05 20:37:01+00', 'wideFormat': False, 'new': False, 'sentDiscord': False, 'featured': False, 'submitted_by': '0x790A4485e5198763C0a34272698ed0cd9506949B', 'twitterCardLocation': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nba-will-the-mavericks-beat-the-grizzlies-by-more-than-5pt5-points-in-their-december-4-matchup.png?1638736245595', 'twitterCardLastRefreshed': '1638736245595', 'archived': False, 'resolvedBy': '0x0dD333859cF16942dd333D7570D839b8946Ac221', 'restricted': False, 'volumeNum': 1335.05, 'liquidityNum': 50, 'endDateIso': '2021-12-04', 'startDateIso': '2021-12-04', 'hasReviewedDates': Tr ...

# %%
def get_all_markets(limit=2) -> "list":
        return get_markets(querystring_params={"limit": limit})

# %%
print(get_all_markets(limit=2))
# Out:
# [{'id': '12', 'question': 'Will Joe Biden get Coronavirus before the election?', 'conditionId': '0xe3b423dfad8c22ff75c9899c4e8176f628cf4ad4caa00481764d320e7415f7a9', 'slug': 'will-joe-biden-get-coronavirus-before-the-election', 'twitterCardImage': 'https://polymarket-static.s3.us-east-2.amazonaws.com/polymarket-twitter-card.png', 'endDate': '2020-11-04T00:00:00Z', 'category': 'US-current-affairs', 'liquidity': '0', 'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-joe-biden-get-coronavirus-before-the-election-5a3d4c3b-0a73-419e-a686-be034d2c73ac.png', 'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-joe-biden-get-coronavirus-before-the-election-5a3d4c3b-0a73-419e-a686-be034d2c73ac.png', 'description': 'This is a market on if presidential candidate Joe Biden will test positive for COVID-19 before November 3rd, 2020. This will be defined as Joe publicly announcing - via any medium, including social media - that he has tested positive for COVID-19, or some variation of that statement. If it is in reference to antibodies, or he doesn’t publicly acknowledge it, the market will resolve to No.\nIn the event of ambiguity in terms of the market outcome, the market will be resolved at the sole discretion of the Markets Integrity Committee (MIC).', 'outcomes': '["Yes", "No"]', 'outcomePrices': '["0", "0"]', 'volume': '32257.445115', 'active': True, 'marketType': 'normal', 'closed': True, 'marketMakerAddress': '0x8BD6C3D7a57D650A1870dd338234f90051fe9918', 'updatedBy': 9, 'createdAt': '2020-10-02T16:10:01.467Z', 'updatedAt': '2024-04-23T00:49:51.620233Z', 'closedTime': '2020-11-02 16:31:01+00', 'mailchimpTag': '3917403', 'archived': False, 'restricted': False, 'volumeNum': 32257.45, 'liquidityNum': 0, 'endDateIso': '2020-11-04', 'hasReviewedDates': True, 'readyForCron': True, 'volume24hr': 0, 'volume1wk': 0, 'volume1mo': 0, 'volume1yr': 0, 'clobTokenIds': '["53135072462907880191400140706440867753044989936304433583131786753949599718775", "60869871469376321574904667328762911501870754872924453995477779862968218702336"]', 'fpmmLive': True, 'volume1wkAmm': 0, 'volume1moAmm': 0, 'volume1yrAmm': 0, 'volume1wkClob': 0, 'volume1moClob': 0, 'volume1yrClob': 0, 'events': [{'id': '4690', 'ticker': 'will-joe-biden-get-coronavirus-before-the-election', 'slug': 'will-joe-biden-get-coronavirus-before-the-election', 'title': 'Will Joe Biden get Coronavirus before the election?', 'description': 'This is a market on if presidential candidate Joe Biden will test positive for COVID-19 before November 3rd, 2020. This will be defined as Joe publicly announcing - via any medium, including social media - that he has tested positive for COVID-19, or some variation of that statement. If it is in reference to antibodies, or he doesn’t publicly acknowledge it, the market will resolve to No.\nIn the event of ambiguity in terms of the market outcome, the market will be resolved at the sole discretion of the Markets Integrity Committee (MIC).', 'startDate': '2020-10-02T00:00:00Z', 'creationDate': '2020-10-02T00:00:00Z', 'endDate': '2020-11-04T00:00:00Z', 'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-joe-biden-get-coronavirus-before-the-election-69e1dbcd-3cfe-4caf-b2af-c00e9ce7186f.png', 'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-joe-biden-get-coronavirus-before-the-election-69e1dbcd-3cfe-4caf-b2af-c00e9ce7186f.png', 'active': True, 'closed': True, 'archived': False, 'featured': False, 'restricted': False, 'liquidity': 0, 'volume': 32257.45, 'openInterest': 0, 'sortBy': 'ascending', 'category': 'US-current-affairs', 'published_at': '2022-07-27 14:41:12.085+00', 'createdAt': '2022-07-27T14:41:12.088Z', 'updatedAt': '2024-04-25T18:57:18.376169Z', 'competitive': 0, 'volume24hr': 0, 'volume1wk': 0, 'volume1mo': 0, 'volume1yr': 0, 'liquidityAmm': 0, 'liquidityClob': 0, 'commentCount': 0, 'cyom': False, 'closedTime': '2022-07-27T14:41:12.088Z', 'showAllOutcomes': False, 'showMarketImages': True, ' ...

# %%
def get_all_events(limit=2) -> "list":
        return get_events(querystring_params={"limit": limit})

# %%
print(get_all_events(limit=2))
# Out:
# [{'id': '2890', 'ticker': 'nba-will-the-mavericks-beat-the-grizzlies-by-more-than-5pt5-points-in-their-december-4-matchup', 'slug': 'nba-will-the-mavericks-beat-the-grizzlies-by-more-than-5pt5-points-in-their-december-4-matchup', 'title': 'NBA: Will the Mavericks beat the Grizzlies by more than 5.5 points in their December 4 matchup?', 'description': 'In the upcoming NBA game, scheduled for December 4:\n\nIf the Dallas Mavericks win by over 5.5 points, the market will resolve to “Yes”.\n\nIf the Memphis Grizzlies lose by less than 5.5 points or win, the market will resolve “No.” \n\nIf the game is not completed by December 11, 2021, the market will resolve 50-50.', 'resolutionSource': 'https://www.nba.com/games', 'startDate': '2021-12-04T00:00:00Z', 'creationDate': '2021-12-04T00:00:00Z', 'endDate': '2021-12-04T00:00:00Z', 'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nba-will-the-mavericks-beat-the-grizzlies-by-more-than-55-points-in-their-december-4-matchup-543e7263-67da-4905-8732-cd3f220ae751.png', 'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nba-will-the-mavericks-beat-the-grizzlies-by-more-than-55-points-in-their-december-4-matchup-543e7263-67da-4905-8732-cd3f220ae751.png', 'active': True, 'closed': True, 'archived': False, 'new': False, 'featured': False, 'restricted': False, 'liquidity': 0, 'volume': 1335.05, 'openInterest': 0, 'sortBy': 'ascending', 'category': 'Sports', 'published_at': '2022-07-27 14:40:02.064+00', 'createdAt': '2022-07-27T14:40:02.074Z', 'updatedAt': '2024-04-25T18:49:06.075795Z', 'competitive': 0, 'volume24hr': 0, 'volume1wk': 0, 'volume1mo': 0, 'volume1yr': 0, 'liquidityAmm': 0, 'liquidityClob': 0, 'commentCount': 8125, 'markets': [{'id': '239826', 'question': 'NBA: Will the Mavericks beat the Grizzlies by more than 5.5 points in their December 4 matchup?', 'conditionId': '0x064d33e3f5703792aafa92bfb0ee10e08f461b1b34c02c1f02671892ede1609a', 'slug': 'nba-will-the-mavericks-beat-the-grizzlies-by-more-than-5pt5-points-in-their-december-4-matchup', 'resolutionSource': 'https://www.nba.com/games', 'endDate': '2021-12-04T00:00:00Z', 'category': 'Sports', 'liquidity': '50.000009', 'startDate': '2021-12-04T19:35:03.796Z', 'fee': '20000000000000000', 'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nba-will-the-mavericks-beat-the-grizzlies-by-more-than-55-points-in-their-december-4-matchup-aa2992d1-38df-404a-9190-49a909775014.png', 'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nba-will-the-mavericks-beat-the-grizzlies-by-more-than-55-points-in-their-december-4-matchup-aa2992d1-38df-404a-9190-49a909775014.png', 'description': 'In the upcoming NBA game, scheduled for December 4:\n\nIf the Dallas Mavericks win by over 5.5 points, the market will resolve to “Yes”.\n\nIf the Memphis Grizzlies lose by less than 5.5 points or win, the market will resolve “No.” \n\nIf the game is not completed by December 11, 2021, the market will resolve 50-50.', 'outcomes': '["Yes", "No"]', 'outcomePrices': '["0.0000004113679809846114013590098187297978", "0.9999995886320190153885986409901813"]', 'volume': '1335.045385', 'active': True, 'marketType': 'normal', 'closed': True, 'marketMakerAddress': '0x9c568Ce9a316e7CF9bCCA352b409dfDdCD9b2C08', 'updatedBy': 15, 'createdAt': '2021-12-04T10:33:13.541Z', 'updatedAt': '2024-04-24T23:35:51.063381Z', 'closedTime': '2021-12-05 20:37:01+00', 'wideFormat': False, 'new': False, 'sentDiscord': False, 'featured': False, 'submitted_by': '0x790A4485e5198763C0a34272698ed0cd9506949B', 'twitterCardLocation': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nba-will-the-mavericks-beat-the-grizzlies-by-more-than-5pt5-points-in-their-december-4-matchup.png?1638736245595', 'twitterCardLastRefreshed': '1638736245595', 'archived': False, 'resolvedBy': '0x0dD333859cF16942dd333D7570D839b8946Ac221', 'restricted': False, 'volumeNum': 1335.05, 'liquidityNum': 50, 'endDateIso': '2021-12-04', 'startDateIso': '2021-12-04', 'hasReviewedDates': Tr ...

# %%
def get_current_markets(limit=4) -> "list":
        return get_markets(
            querystring_params={
                "active": True,
                "closed": False,
                "archived": False,
                "limit": limit,
            }
        )

# %%
print(get_current_markets(limit=4))
# Out:
# [{'id': '516710', 'question': 'US recession in 2025?', 'conditionId': '0xfa48a99317daef1654d5b03e30557c4222f276657275628d9475e141c64b545d', 'slug': 'us-recession-in-2025', 'resolutionSource': '', 'endDate': '2026-02-28T12:00:00Z', 'liquidity': '96326.4307', 'startDate': '2025-01-08T01:33:54.924Z', 'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/us-recession-in-2025-01ZjnLjvO4a3.jpg', 'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/us-recession-in-2025-01ZjnLjvO4a3.jpg', 'description': 'This market will resolve to “Yes”, if either of the following conditions are met:\n\n1.  The National Bureau of Economic Research (NBER) publicly announces that a recession has occurred in the United States, at any point in 2025, with the announcement made by December 31, 2025, 11:59 PM ET.\n\n2.  The seasonally adjusted annualized percent change in quarterly U.S. real GDP from the previous quarter is less than 0.0 for two consecutive quarters between Q4 2024 and Q4 2025 (inclusive), as reported by the Bureau of Economic Analysis (BEA). \n\nOtherwise, this market will resolve to "No". \n\nNote that advance estimates will be considered. For example, if upon release, the advance estimate for Q2 2025 was negative, and the Q1 2025\'s most recent, up-to-date estimate was also negative, this market would resolve to "Yes". If on December 31, 2025 the latest estimate for quarterly GDP in Q3 2025 was negative, this market will stay open until the Advance estimate of Q4 2025 is published, at which point it will resolve to "Yes" if Q4 2025 was negative or if the NBER declares a recession by then.\n\nThe resolution source will be the official announcements from the NBER and the BEA’s estimate of seasonally adjusted annualized percent change in quarterly US real GDP from previous quarters as released by the Bureau of Economic Analysis (BEA), https://www.bea.gov/data/gdp/gross-domestic-product', 'outcomes': '["Yes", "No"]', 'outcomePrices': '["0.0115", "0.9885"]', 'volume': '10969901.862152', 'active': True, 'closed': False, 'marketMakerAddress': '', 'createdAt': '2024-12-29T18:04:31.897422Z', 'updatedAt': '2025-12-20T03:54:20.166347Z', 'new': False, 'featured': True, 'submitted_by': '0x91430CaD2d3975766499717fA0D66A78D814E5c5', 'archived': False, 'resolvedBy': '0x6A9D222616C90FcA5754cd1333cFD9b7fb6a4F74', 'restricted': True, 'groupItemTitle': '', 'groupItemThreshold': '0', 'questionID': '0xd87778fac13b570524bc8e8056bc235b3d696ecfcbe39afd754daca0741c419b', 'enableOrderBook': True, 'orderPriceMinTickSize': 0.001, 'orderMinSize': 5, 'volumeNum': 10969901.862152, 'liquidityNum': 96326.4307, 'endDateIso': '2026-02-28', 'startDateIso': '2025-01-08', 'hasReviewedDates': True, 'volume24hr': 22320.581013, 'volume1wk': 291074.55847799993, 'volume1mo': 778671.9075589996, 'volume1yr': 10965563.785761056, 'clobTokenIds': '["104173557214744537570424345347209544585775842950109756851652855913015295701992", "44528029102356085806317866371026691780796471200782980570839327755136990994869"]', 'umaBond': '500', 'umaReward': '5', 'volume24hrClob': 22320.581013, 'volume1wkClob': 291074.55847799993, 'volume1moClob': 778671.9075589996, 'volume1yrClob': 10965563.785761056, 'volumeClob': 10969901.862152, 'liquidityClob': 96326.4307, 'acceptingOrders': True, 'negRisk': False, 'events': [{'id': '16092', 'ticker': 'us-recession-in-2025', 'slug': 'us-recession-in-2025', 'title': 'US recession in 2025?', 'description': 'This market will resolve to “Yes”, if either of the following conditions are met:\n\n1.  The National Bureau of Economic Research (NBER) publicly announces that a recession has occurred in the United States, at any point in 2025, with the announcement made by December 31, 2025, 11:59 PM ET.\n\n2.  The seasonally adjusted annualized percent change in quarterly U.S. real GDP from the previous quarter is less than 0.0 for two consecutive quarters between Q4 2024 and Q4 2025 (inclusive), as reported by the Bureau of Economic Analysis (BEA). \n\nOther ...

# %%
def get_all_current_markets(limit=100) -> "list":
        offset = 0
        all_markets = []
        while True:
            params = {
                "active": True,
                "closed": False,
                "archived": False,
                "limit": limit,
                "offset": offset,
            }
            market_batch = get_markets(querystring_params=params)
            all_markets.extend(market_batch)

            if len(market_batch) < limit:
                break
            offset += limit

        return all_markets

# %%
print(get_all_current_markets(limit=100))
# Out:
# Buffered data was truncated after reaching the output size limit.

# %%
def get_closed_markets(limit=4, local_file_path=None) -> "list":
        return get_markets(
            querystring_params={
                # "active": True,
                "closed": True,
                # "archived": False,
                "limit": limit,
            }, local_file_path=local_file_path
        )

# %%
get_closed_markets(limit=4, local_file_path="closed_markets.json")
# Out:
# [{'id': '12',
#   'question': 'Will Joe Biden get Coronavirus before the election?',
#   'conditionId': '0xe3b423dfad8c22ff75c9899c4e8176f628cf4ad4caa00481764d320e7415f7a9',
#   'slug': 'will-joe-biden-get-coronavirus-before-the-election',
#   'twitterCardImage': 'https://polymarket-static.s3.us-east-2.amazonaws.com/polymarket-twitter-card.png',
#   'endDate': '2020-11-04T00:00:00Z',
#   'category': 'US-current-affairs',
#   'liquidity': '0',
#   'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-joe-biden-get-coronavirus-before-the-election-5a3d4c3b-0a73-419e-a686-be034d2c73ac.png',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-joe-biden-get-coronavirus-before-the-election-5a3d4c3b-0a73-419e-a686-be034d2c73ac.png',
#   'description': 'This is a market on if presidential candidate Joe Biden will test positive for COVID-19 before November 3rd, 2020. This will be defined as Joe publicly announcing - via any medium, including social media - that he has tested positive for COVID-19, or some variation of that statement. If it is in reference to antibodies, or he doesn’t publicly acknowledge it, the market will resolve to No.\nIn the event of ambiguity in terms of the market outcome, the market will be resolved at the sole discretion of the Markets Integrity Committee (MIC).',
#   'outcomes': '["Yes", "No"]',
#   'outcomePrices': '["0", "0"]',
#   'volume': '32257.445115',
#   'active': True,
#   'marketType': 'normal',
#   'closed': True,
#   'marketMakerAddress': '0x8BD6C3D7a57D650A1870dd338234f90051fe9918',
#   'updatedBy': 9,
#   'createdAt': '2020-10-02T16:10:01.467Z',
#   'updatedAt': '2024-04-23T00:49:51.620233Z',
#   'closedTime': '2020-11-02 16:31:01+00',
#   'mailchimpTag': '3917403',
#   'archived': False,
#   'restricted': False,
#   'volumeNum': 32257.45,
#   'liquidityNum': 0,
#   'endDateIso': '2020-11-04',
#   'hasReviewedDates': True,
#   'readyForCron': True,
#   'volume24hr': 0,
#   'volume1wk': 0,
#   'volume1mo': 0,
#   'volume1yr': 0,
#   'clobTokenIds': '["53135072462907880191400140706440867753044989936304433583131786753949599718775", "60869871469376321574904667328762911501870754872924453995477779862968218702336"]',
#   'fpmmLive': True,
#   'volume1wkAmm': 0,
#   'volume1moAmm': 0,
#   'volume1yrAmm': 0,
#   'volume1wkClob': 0,
#   'volume1moClob': 0,
#   'volume1yrClob': 0,
#   'events': [{'id': '4690',
#     'ticker': 'will-joe-biden-get-coronavirus-before-the-election',
#     'slug': 'will-joe-biden-get-coronavirus-before-the-election',
#     'title': 'Will Joe Biden get Coronavirus before the election?',
#     'description': 'This is a market on if presidential candidate Joe Biden will test positive for COVID-19 before November 3rd, 2020. This will be defined as Joe publicly announcing - via any medium, including social media - that he has tested positive for COVID-19, or some variation of that statement. If it is in reference to antibodies, or he doesn’t publicly acknowledge it, the market will resolve to No.\nIn the event of ambiguity in terms of the market outcome, the market will be resolved at the sole discretion of the Markets Integrity Committee (MIC).',
#     'startDate': '2020-10-02T00:00:00Z',
#     'creationDate': '2020-10-02T00:00:00Z',
#     'endDate': '2020-11-04T00:00:00Z',
#     'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-joe-biden-get-coronavirus-before-the-election-69e1dbcd-3cfe-4caf-b2af-c00e9ce7186f.png',
#     'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-joe-biden-get-coronavirus-before-the-election-69e1dbcd-3cfe-4caf-b2af-c00e9ce7186f.png',
#     'active': True,
#     'closed': True,
#     'archived': False,
#     'featured': False,
#     'restricted': False,
#     'liquidity': 0,
#     'volume': 32257.45,
#     'openInterest': 0,
#     'sortBy': 'ascending',
#     'category': 'US-current-affairs',
#     'published_at': '2022-07-27 14:41:12.085+00',
#     'createdAt': '2022-07-27T14:41:12.088Z',
#     'updatedAt': '2024-04-25T18:57:18.376169Z',
#     'competitive': 0,
#     'volume24hr': 0,
#     'volume1wk': 0,
#     'volume1mo': 0,
#     'volume1yr': 0,
#     'liquidityAmm': 0,
#     'liquidityClob': 0,
#     'commentCount': 0,
#     'cyom': False,
#     'closedTime': '2022-07-27T14:41:12.088Z',
#     'showAllOutcomes': False,
#     'showMarketImages': True,
#     'enableNegRisk': False,
#     'negRiskAugmented': False,
#     'pendingDeployment': False,
#     'deploying': False,
#     'requiresTranslation': False}],
#   'creator': '',
#   'ready': False,
#   'funded': False,
#   'cyom': False,
#   'competitive': 0,
#   'pagerDutyNotificationEnabled': False,
#   'approved': True,
#   'rewardsMinSize': 0,
#   'rewardsMaxSpread': 0,
#   'spread': 1,
#   'oneDayPriceChange': 0,
#   'oneHourPriceChange': 0,
#   'oneWeekPriceChange': 0,
#   'oneMonthPriceChange': 0,
#   'oneYearPriceChange': 0,
#   'lastTradePrice': 0,
#   'bestBid': 0,
#   'bestAsk': 1,
#   'clearBookOnStart': True,
#   'manualActivation': False,
#   'negRiskOther': False,
#   'umaResolutionStatuses': '[]',
#   'pendingDeployment': False,
#   'deploying': False,
#   'rfqEnabled': False,
#   'holdingRewardsEnabled': False,
#   'feesEnabled': False,
#   'requiresTranslation': False},
#  {'id': '17',
#   'question': 'Will Airbnb begin publicly trading before Jan 1, 2021?',
#   'conditionId': '0x44f10d1cd5aaed4b7ae0b5edb76790f54f45dc0bcaa86831c83d865c774fbb90',
#   'slug': 'will-airbnb-begin-publicly-trading-before-jan-1-2021',
#   'twitterCardImage': 'https://polymarket-static.s3.us-east-2.amazonaws.com/polymarket-twitter-card.png',
#   'endDate': '2021-01-02T00:00:00Z',
#   'category': 'Tech',
#   'liquidity': '0',
#   'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-airbnb-begin-publicly-trading-before-jan-1-2021-c1ba5f2f-c025-486a-9664-15cd8d4ac91b.png',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-airbnb-begin-publicly-trading-before-jan-1-2021-c1ba5f2f-c025-486a-9664-15cd8d4ac91b.png',
#   'description': 'This market is on whether or not Airbnb will be a publicly traded company by January 1, 2021. This market will resolve to Yes if Airbnb starts publicly trading on NASDAQ or NYSE before January 1st 2021, regardless of if they list via IPO, direct listing, or some other method. If they are not listed and publicly trading on one of those 2 stock exchanges, the market will resolve to "No". In the event of ambiguity in terms of the market outcome, the market will be resolved at the sole discretion of the Markets Integrity Committee (MIC).\n',
#   'outcomes': '["Yes", "No"]',
#   'outcomePrices': '["0", "0"]',
#   'volume': '89665.252158',
#   'active': True,
#   'marketType': 'normal',
#   'closed': True,
#   'marketMakerAddress': '0x3d3dB3BeE80414717e3C66c341EF95eCc9BDDBaB',
#   'updatedBy': 3,
#   'createdAt': '2020-10-02T19:20:04.234Z',
#   'updatedAt': '2024-04-23T00:31:22.863043Z',
#   'closedTime': '2020-12-11 20:53:24+00',
#   'archived': False,
#   'restricted': False,
#   'volumeNum': 89665.25,
#   'liquidityNum': 0,
#   'endDateIso': '2021-01-02',
#   'hasReviewedDates': True,
#   'readyForCron': True,
#   'volume24hr': 0,
#   'volume1wk': 0,
#   'volume1mo': 0,
#   'volume1yr': 0,
#   'clobTokenIds': '["23957885615115430922384185661294483989521212430808224513177413172438775950057", "44065917169138815451032058926556960033374557137879250075091545322436931840853"]',
#   'fpmmLive': True,
#   'volume1wkAmm': 0,
#   'volume1moAmm': 0,
#   'volume1yrAmm': 0,
#   'volume1wkClob': 0,
#   'volume1moClob': 0,
#   'volume1yrClob': 0,
#   'events': [{'id': '3917',
#     'ticker': 'will-airbnb-begin-publicly-trading-before-jan-1-2021',
#     'slug': 'will-airbnb-begin-publicly-trading-before-jan-1-2021',
#     'title': 'Will Airbnb begin publicly trading before Jan 1, 2021?',
#     'description': 'This market is on whether or not Airbnb will be a publicly traded company by January 1, 2021. This market will resolve to Yes if Airbnb starts publicly trading on NASDAQ or NYSE before January 1st 2021, regardless of if they list via IPO, direct listing, or some other method. If they are not listed and publicly trading on one of those 2 stock exchanges, the market will resolve to "No". In the event of ambiguity in terms of the market outcome, the market will be resolved at the sole discretion of the Markets Integrity Committee (MIC).\n',
#     'startDate': '2020-10-02T00:00:00Z',
#     'creationDate': '2020-10-02T00:00:00Z',
#     'endDate': '2021-01-02T00:00:00Z',
#     'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-airbnb-begin-publicly-trading-before-jan-1-2021-1767f08a-6651-42b2-9527-73f7be08fd08.png',
#     'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-airbnb-begin-publicly-trading-before-jan-1-2021-1767f08a-6651-42b2-9527-73f7be08fd08.png',
#     'active': True,
#     'closed': True,
#     'archived': False,
#     'featured': False,
#     'restricted': False,
#     'liquidity': 0,
#     'volume': 89665.25,
#     'openInterest': 0,
#     'sortBy': 'ascending',
#     'category': 'Tech',
#     'published_at': '2022-07-27 14:40:42.971+00',
#     'createdAt': '2022-07-27T14:40:42.974Z',
#     'updatedAt': '2024-04-23T22:47:12.642921Z',
#     'competitive': 0,
#     'volume24hr': 0,
#     'volume1wk': 0,
#     'volume1mo': 0,
#     'volume1yr': 0,
#     'liquidityAmm': 0,
#     'liquidityClob': 0,
#     'commentCount': 0,
#     'cyom': False,
#     'closedTime': '2022-07-27T14:40:42.974Z',
#     'showAllOutcomes': False,
#     'showMarketImages': True,
#     'enableNegRisk': False,
#     'negRiskAugmented': False,
#     'pendingDeployment': False,
#     'deploying': False,
#     'requiresTranslation': False}],
#   'creator': '',
#   'ready': False,
#   'funded': False,
#   'cyom': False,
#   'competitive': 0,
#   'pagerDutyNotificationEnabled': False,
#   'approved': True,
#   'rewardsMinSize': 0,
#   'rewardsMaxSpread': 0,
#   'spread': 1,
#   'oneDayPriceChange': 0,
#   'oneHourPriceChange': 0,
#   'oneWeekPriceChange': 0,
#   'oneMonthPriceChange': 0,
#   'oneYearPriceChange': 0,
#   'lastTradePrice': 0,
#   'bestBid': 0,
#   'bestAsk': 1,
#   'clearBookOnStart': True,
#   'manualActivation': False,
#   'negRiskOther': False,
#   'umaResolutionStatuses': '[]',
#   'pendingDeployment': False,
#   'deploying': False,
#   'rfqEnabled': False,
#   'holdingRewardsEnabled': False,
#   'feesEnabled': False,
#   'requiresTranslation': False},
#  {'id': '18',
#   'question': 'Will a new Supreme Court Justice be confirmed before Nov 3rd, 2020?',
#   'conditionId': '0x3e0524de013d9dc359f5eb370773f25de2f03d3200294cfd0fa7dac2f399d101',
#   'slug': 'will-a-new-supreme-court-justice-be-confirmed-before-nov-3rd-2020',
#   'twitterCardImage': 'https://polymarket-static.s3.us-east-2.amazonaws.com/polymarket-twitter-card.png',
#   'endDate': '2020-11-04T00:00:00Z',
#   'category': 'US-current-affairs',
#   'liquidity': '0',
#   'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-a-new-supreme-court-justice-be-confirmed-before-nov-3rd-2020-9799dac2-a822-41bf-909a-cdc8eee8ec3e.png',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-a-new-supreme-court-justice-be-confirmed-before-nov-3rd-2020-9799dac2-a822-41bf-909a-cdc8eee8ec3e.png',
#   'description': 'This is a market on whether or not a new Supreme Court Justice will be both nominated and confirmed before Nov 3rd, 2020. Nominated and Confirmed, in the context of the Supreme Court, are defined here: https://en.wikipedia.org/wiki/Appointment_and_confirmation_to_the_Supreme_Court_of_the_United_States. If a Supreme Court Justice is Nominated but not Confirmed before the election, the market will resolve to “No”. RIP RBG. In the event of ambiguity in terms of the market outcome, the market will be resolved at the sole discretion of the Markets Integrity Committee (MIC).',
#   'outcomes': '["Yes", "No"]',
#   'outcomePrices': '["0", "0"]',
#   'volume': '43279.456005',
#   'active': True,
#   'marketType': 'normal',
#   'closed': True,
#   'marketMakerAddress': '0x01a4333b6aCb5091cF0219646f35E289546F4656',
#   'updatedBy': 9,
#   'createdAt': '2020-10-02T19:20:04.234Z',
#   'updatedAt': '2024-04-22T23:52:06.957229Z',
#   'closedTime': '2020-10-27 00:40:55+00',
#   'mailchimpTag': '3917431',
#   'archived': False,
#   'restricted': False,
#   'volumeNum': 43279.46,
#   'liquidityNum': 0,
#   'endDateIso': '2022-01-27',
#   'hasReviewedDates': True,
#   'readyForCron': True,
#   'volume24hr': 0,
#   'volume1wk': 0,
#   'volume1mo': 0,
#   'volume1yr': 0,
#   'clobTokenIds': '["7192973530925903015287004813226256961086727269646918334118953338356315960259", "16847315704461293231139078524698349110433698045131366205472540524863290566139"]',
#   'fpmmLive': True,
#   'volume1wkAmm': 0,
#   'volume1moAmm': 0,
#   'volume1yrAmm': 0,
#   'volume1wkClob': 0,
#   'volume1moClob': 0,
#   'volume1yrClob': 0,
#   'events': [{'id': '5098',
#     'ticker': 'will-a-new-supreme-court-justice-be-confirmed-before-nov-3rd-2020',
#     'slug': 'will-a-new-supreme-court-justice-be-confirmed-before-nov-3rd-2020',
#     'title': 'Will a new Supreme Court Justice be confirmed before Nov 3rd, 2020?',
#     'description': 'This is a market on whether or not a new Supreme Court Justice will be both nominated and confirmed before Nov 3rd, 2020. Nominated and Confirmed, in the context of the Supreme Court, are defined here: https://en.wikipedia.org/wiki/Appointment_and_confirmation_to_the_Supreme_Court_of_the_United_States. If a Supreme Court Justice is Nominated but not Confirmed before the election, the market will resolve to “No”. RIP RBG. In the event of ambiguity in terms of the market outcome, the market will be resolved at the sole discretion of the Markets Integrity Committee (MIC).',
#     'startDate': '2020-10-02T00:00:00Z',
#     'creationDate': '2020-10-02T00:00:00Z',
#     'endDate': '2022-01-27T00:00:00Z',
#     'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-a-new-supreme-court-justice-be-confirmed-before-nov-3rd-2020-3c76e3ef-bf2f-4ca3-962b-fed3155516e8.png',
#     'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-a-new-supreme-court-justice-be-confirmed-before-nov-3rd-2020-3c76e3ef-bf2f-4ca3-962b-fed3155516e8.png',
#     'active': True,
#     'closed': True,
#     'archived': False,
#     'featured': False,
#     'restricted': False,
#     'liquidity': 0,
#     'volume': 43279.46,
#     'openInterest': 0,
#     'sortBy': 'ascending',
#     'category': 'US-current-affairs',
#     'published_at': '2022-07-27 14:41:27.361+00',
#     'createdAt': '2022-07-27T14:41:27.364Z',
#     'updatedAt': '2024-04-25T18:56:11.18445Z',
#     'competitive': 0,
#     'volume24hr': 0,
#     'volume1wk': 0,
#     'volume1mo': 0,
#     'volume1yr': 0,
#     'liquidityAmm': 0,
#     'liquidityClob': 0,
#     'commentCount': 0,
#     'cyom': False,
#     'closedTime': '2022-07-27T14:41:27.364Z',
#     'showAllOutcomes': False,
#     'showMarketImages': True,
#     'enableNegRisk': False,
#     'negRiskAugmented': False,
#     'pendingDeployment': False,
#     'deploying': False,
#     'requiresTranslation': False}],
#   'creator': '',
#   'ready': False,
#   'funded': False,
#   'cyom': False,
#   'competitive': 0,
#   'pagerDutyNotificationEnabled': False,
#   'approved': True,
#   'rewardsMinSize': 0,
#   'rewardsMaxSpread': 0,
#   'spread': 1,
#   'oneDayPriceChange': 0,
#   'oneHourPriceChange': 0,
#   'oneWeekPriceChange': 0,
#   'oneMonthPriceChange': 0,
#   'oneYearPriceChange': 0,
#   'lastTradePrice': 0,
#   'bestBid': 0,
#   'bestAsk': 1,
#   'clearBookOnStart': True,
#   'manualActivation': False,
#   'negRiskOther': False,
#   'umaResolutionStatuses': '[]',
#   'pendingDeployment': False,
#   'deploying': False,
#   'rfqEnabled': False,
#   'holdingRewardsEnabled': False,
#   'feesEnabled': False,
#   'requiresTranslation': False},
#  {'id': '19',
#   'question': 'Will Kim Kardashian and Kanye West divorce before Jan 1, 2021?',
#   'conditionId': '0x9b946f54f3428aafc308c33aa04a943fe13a011bdac9a9b66e1ba16c416ca256',
#   'slug': 'will-kim-kardashian-and-kanye-west-divorce-before-jan-1-2021',
#   'twitterCardImage': 'https://polymarket-static.s3.us-east-2.amazonaws.com/polymarket-twitter-card.png',
#   'endDate': '2021-01-02T00:00:00Z',
#   'category': 'Pop-Culture ',
#   'liquidity': '0.179651',
#   'startDate': '2023-08-24T16:35:24.938Z',
#   'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-kim-kardashian-and-kanye-west-divorce-before-jan-1-2021-56c39e78-0a04-4827-bf52-d2c1052f82d9.png',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-kim-kardashian-and-kanye-west-divorce-before-jan-1-2021-56c39e78-0a04-4827-bf52-d2c1052f82d9.png',
#   'description': 'This is a market on whether Kanye West and Kim Kardashian will officially file for a divorce before January 1st 2021. Divorce can be defined empirically as either an official announcement direct from either Kim or Kanye, or an official filing of divorce, including but not limited to certified copies of divorce decrees available from the Superior Court in the county where the decree was granted. This market will resolve "Yes" if the aforementioned conditions are met and "No" otherwise. In the event of ambiguity in terms of the market outcome, the market will be resolved at the sole discretion of the Markets Integrity Committee (MIC).\n',
#   'outcomes': '["Yes", "No"]',
#   'outcomePrices': '["0.000001011082052522541417308141468657552", "0.9999989889179474774585826918585313"]',
#   'volume': '22067.475119',
#   'active': True,
#   'marketType': 'normal',
#   'closed': True,
#   'marketMakerAddress': '0x13064324dFF1e76062975345d255EFccc6C78bd0',
#   'updatedBy': 126,
#   'createdAt': '2020-10-02T19:20:04.234Z',
#   'updatedAt': '2024-04-26T02:45:04.309477Z',
#   'closedTime': '2021-01-02 21:35:34+00',
#   'mailchimpTag': '4102440',
#   'archived': False,
#   'restricted': False,
#   'volumeNum': 22067.48,
#   'liquidityNum': 0.18,
#   'endDateIso': '2021-01-02',
#   'hasReviewedDates': True,
#   'readyForCron': True,
#   'volume24hr': 0,
#   'volume1wk': 0,
#   'volume1mo': 0,
#   'volume1yr': 0,
#   'clobTokenIds': '["4485468797843270805361907688585033105060134197906764657766452761383944608702", "99620935296034450526138833612193162137893979576079468831519296537203486531810"]',
#   'fpmmLive': True,
#   'volume1wkAmm': 0,
#   'volume1moAmm': 0,
#   'volume1yrAmm': 0,
#   'volume1wkClob': 0,
#   'volume1moClob': 0,
#   'volume1yrClob': 0,
#   'liquidityAmm': 0.18,
#   'events': [{'id': '4870',
#     'ticker': 'will-kim-kardashian-and-kanye-west-divorce-before-jan-1-2021',
#     'slug': 'will-kim-kardashian-and-kanye-west-divorce-before-jan-1-2021',
#     'title': 'Will Kim Kardashian and Kanye West divorce before Jan 1, 2021?',
#     'description': 'This is a market on whether Kanye West and Kim Kardashian will officially file for a divorce before January 1st 2021. Divorce can be defined empirically as either an official announcement direct from either Kim or Kanye, or an official filing of divorce, including but not limited to certified copies of divorce decrees available from the Superior Court in the county where the decree was granted. This market will resolve "Yes" if the aforementioned conditions are met and "No" otherwise. In the event of ambiguity in terms of the market outcome, the market will be resolved at the sole discretion of the Markets Integrity Committee (MIC).\n',
#     'startDate': '2020-10-02T00:00:00Z',
#     'creationDate': '2020-10-02T00:00:00Z',
#     'endDate': '2021-01-02T00:00:00Z',
#     'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-kim-kardashian-and-kanye-west-divorce-before-jan-1-2021-72891edd-88ea-41fb-86ac-7623838d49b0.png',
#     'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-kim-kardashian-and-kanye-west-divorce-before-jan-1-2021-72891edd-88ea-41fb-86ac-7623838d49b0.png',
#     'active': True,
#     'closed': True,
#     'archived': False,
#     'featured': False,
#     'restricted': False,
#     'liquidity': 0,
#     'volume': 22067.48,
#     'openInterest': 0,
#     'sortBy': 'ascending',
#     'category': 'Pop-Culture ',
#     'published_at': '2022-07-27 14:41:18.863+00',
#     'createdAt': '2022-07-27T14:41:18.866Z',
#     'updatedAt': '2024-04-25T19:57:53.317939Z',
#     'competitive': 0,
#     'volume24hr': 0,
#     'volume1wk': 0,
#     'volume1mo': 0,
#     'volume1yr': 0,
#     'liquidityAmm': 0,
#     'liquidityClob': 0,
#     'commentCount': 0,
#     'cyom': False,
#     'closedTime': '2022-07-27T14:41:18.866Z',
#     'showAllOutcomes': False,
#     'showMarketImages': True,
#     'enableNegRisk': False,
#     'negRiskAugmented': False,
#     'pendingDeployment': False,
#     'deploying': False,
#     'requiresTranslation': False}],
#   'creator': '',
#   'ready': False,
#   'funded': False,
#   'cyom': False,
#   'competitive': 0,
#   'pagerDutyNotificationEnabled': False,
#   'approved': True,
#   'rewardsMinSize': 0,
#   'rewardsMaxSpread': 0,
#   'spread': 1,
#   'oneDayPriceChange': 0,
#   'oneHourPriceChange': 0,
#   'oneWeekPriceChange': 0,
#   'oneMonthPriceChange': 0,
#   'oneYearPriceChange': 0,
#   'lastTradePrice': 0,
#   'bestBid': 0,
#   'bestAsk': 1,
#   'clearBookOnStart': True,
#   'manualActivation': False,
#   'negRiskOther': False,
#   'umaResolutionStatuses': '[]',
#   'pendingDeployment': False,
#   'deploying': False,
#   'rfqEnabled': False,
#   'holdingRewardsEnabled': False,
#   'feesEnabled': False,
#   'requiresTranslation': False}]

# %%
print(get_closed_markets(limit=4))
# Out:
# [{'id': '12', 'question': 'Will Joe Biden get Coronavirus before the election?', 'conditionId': '0xe3b423dfad8c22ff75c9899c4e8176f628cf4ad4caa00481764d320e7415f7a9', 'slug': 'will-joe-biden-get-coronavirus-before-the-election', 'twitterCardImage': 'https://polymarket-static.s3.us-east-2.amazonaws.com/polymarket-twitter-card.png', 'endDate': '2020-11-04T00:00:00Z', 'category': 'US-current-affairs', 'liquidity': '0', 'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-joe-biden-get-coronavirus-before-the-election-5a3d4c3b-0a73-419e-a686-be034d2c73ac.png', 'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-joe-biden-get-coronavirus-before-the-election-5a3d4c3b-0a73-419e-a686-be034d2c73ac.png', 'description': 'This is a market on if presidential candidate Joe Biden will test positive for COVID-19 before November 3rd, 2020. This will be defined as Joe publicly announcing - via any medium, including social media - that he has tested positive for COVID-19, or some variation of that statement. If it is in reference to antibodies, or he doesn’t publicly acknowledge it, the market will resolve to No.\nIn the event of ambiguity in terms of the market outcome, the market will be resolved at the sole discretion of the Markets Integrity Committee (MIC).', 'outcomes': '["Yes", "No"]', 'outcomePrices': '["0", "0"]', 'volume': '32257.445115', 'active': True, 'marketType': 'normal', 'closed': True, 'marketMakerAddress': '0x8BD6C3D7a57D650A1870dd338234f90051fe9918', 'updatedBy': 9, 'createdAt': '2020-10-02T16:10:01.467Z', 'updatedAt': '2024-04-23T00:49:51.620233Z', 'closedTime': '2020-11-02 16:31:01+00', 'mailchimpTag': '3917403', 'archived': False, 'restricted': False, 'volumeNum': 32257.45, 'liquidityNum': 0, 'endDateIso': '2020-11-04', 'hasReviewedDates': True, 'readyForCron': True, 'volume24hr': 0, 'volume1wk': 0, 'volume1mo': 0, 'volume1yr': 0, 'clobTokenIds': '["53135072462907880191400140706440867753044989936304433583131786753949599718775", "60869871469376321574904667328762911501870754872924453995477779862968218702336"]', 'fpmmLive': True, 'volume1wkAmm': 0, 'volume1moAmm': 0, 'volume1yrAmm': 0, 'volume1wkClob': 0, 'volume1moClob': 0, 'volume1yrClob': 0, 'events': [{'id': '4690', 'ticker': 'will-joe-biden-get-coronavirus-before-the-election', 'slug': 'will-joe-biden-get-coronavirus-before-the-election', 'title': 'Will Joe Biden get Coronavirus before the election?', 'description': 'This is a market on if presidential candidate Joe Biden will test positive for COVID-19 before November 3rd, 2020. This will be defined as Joe publicly announcing - via any medium, including social media - that he has tested positive for COVID-19, or some variation of that statement. If it is in reference to antibodies, or he doesn’t publicly acknowledge it, the market will resolve to No.\nIn the event of ambiguity in terms of the market outcome, the market will be resolved at the sole discretion of the Markets Integrity Committee (MIC).', 'startDate': '2020-10-02T00:00:00Z', 'creationDate': '2020-10-02T00:00:00Z', 'endDate': '2020-11-04T00:00:00Z', 'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-joe-biden-get-coronavirus-before-the-election-69e1dbcd-3cfe-4caf-b2af-c00e9ce7186f.png', 'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-joe-biden-get-coronavirus-before-the-election-69e1dbcd-3cfe-4caf-b2af-c00e9ce7186f.png', 'active': True, 'closed': True, 'archived': False, 'featured': False, 'restricted': False, 'liquidity': 0, 'volume': 32257.45, 'openInterest': 0, 'sortBy': 'ascending', 'category': 'US-current-affairs', 'published_at': '2022-07-27 14:41:12.085+00', 'createdAt': '2022-07-27T14:41:12.088Z', 'updatedAt': '2024-04-25T18:57:18.376169Z', 'competitive': 0, 'volume24hr': 0, 'volume1wk': 0, 'volume1mo': 0, 'volume1yr': 0, 'liquidityAmm': 0, 'liquidityClob': 0, 'commentCount': 0, 'cyom': False, 'closedTime': '2022-07-27T14:41:12.088Z', 'showAllOutcomes': False, 'showMarketImages': True, ' ...

# %%
def stream_all_closed_markets_to_file(
    limit=100,
    sleep_sec=0.3,
    out_file=None
):
    offset = 0
    total = 0

    with open(out_file, "w", encoding="utf-8") as f:
        while True:
            params = {
                "closed": True,
                "limit": limit,
                "offset": offset,
            }

            try:
                batch = get_markets(querystring_params=params)
            except Exception as e:
                print("retry...")
                time.sleep(2)
                continue

            if not batch:
                break

            for market in batch:
                f.write(json.dumps(market) + "\n")
                total += 1

            print(f"saved {total}")

            if len(batch) < limit:
                break

            offset += limit
            time.sleep(sleep_sec)

    print(f"done, total={total}")

# %%
stream_all_closed_markets_to_file(limit=100, sleep_sec=0.3, out_file="all_closed_markets.jsonl")
# Out:
# saved 100
# saved 200
# saved 300
# saved 400
# saved 500
# saved 600
# saved 700
# saved 800
# saved 900
# saved 1000
# saved 1100
# saved 1200
# saved 1300
# saved 1400
# saved 1500
# saved 1600
# saved 1700
# saved 1800
# saved 1900
# saved 2000
# saved 2100
# saved 2200
# saved 2300
# saved 2400
# saved 2500
# saved 2600
# saved 2700
# saved 2800
# saved 2900
# saved 3000
# saved 3100
# saved 3200
# saved 3300
# saved 3400
# saved 3500
# saved 3600
# saved 3700
# saved 3800
# saved 3900
# saved 4000
# saved 4100
# saved 4200
# saved 4300
# saved 4400
# saved 4500
# saved 4600
# saved 4700
# saved 4800
# saved 4900
# saved 5000
# saved 5100
# saved 5200
# saved 5300
# saved 5400
# saved 5500
# saved 5600
# saved 5700
# saved 5800
# saved 5900
# saved 6000
# saved 6100
# saved 6200
# saved 6300
# saved 6400
# saved 6500
# saved 6600
# saved 6700
# saved 6800
# saved 6900
# saved 7000
# saved 7100
# saved 7200
# saved 7300
# saved 7400
# saved 7500
# saved 7600
# saved 7700
# saved 7800
# saved 7900
# saved 8000
# saved 8100
# saved 8200
# saved 8300
# saved 8400
# saved 8500
# saved 8600
# saved 8700
# saved 8800
# saved 8900
# saved 9000
# saved 9100
# saved 9200
# saved 9300
# saved 9400
# saved 9500
# saved 9600
# saved 9700
# saved 9800
# saved 9900
# saved 10000
# saved 10100
# saved 10200
# saved 10300
# saved 10400
# saved 10500
# saved 10600
# saved 10700
# saved 10800
# saved 10900
# saved 11000
# saved 11100
# saved 11200
# saved 11300
# saved 11400
# saved 11500
# saved 11600
# saved 11700
# saved 11800
# saved 11900
# saved 12000
# saved 12100
# saved 12200
# saved 12300
# saved 12400
# saved 12500
# saved 12600
# saved 12700
# saved 12800
# saved 12900
# saved 13000
# saved 13100
# saved 13200
# saved 13300
# saved 13400
# saved 13500
# saved 13600
# saved 13700
# saved 13800
# saved 13900
# saved 14000
# saved 14100
# saved 14200
# saved 14300
# saved 14400
# saved 14500
# saved 14600
# saved 14700
# saved 14800
# saved 14900
# saved 15000
# saved 15100
# saved 15200
# saved 15300
# saved 15400
# saved 15500
# saved 15600
# saved 15700
# saved 15800
# saved 15900
# saved 16000
# saved 16100
# saved 16200
# saved 16300
# saved 16400
# saved 16500
# saved 16600
# saved 16700
# saved 16800
# saved 16900
# saved 17000
# saved 17100
# saved 17200
# saved 17300
# saved 17400
# saved 17500
# saved 17600
# saved 17700
# saved 17800
# saved 17900
# saved 18000
# saved 18100
# saved 18200
# saved 18300
# saved 18400
# saved 18500
# saved 18600
# saved 18700
# saved 18800
# saved 18900
# saved 19000
# saved 19100
# saved 19200
# saved 19300
# saved 19400
# saved 19500
# saved 19600
# saved 19700
# saved 19800
# saved 19900
# saved 20000
# saved 20100
# saved 20200
# saved 20300
# saved 20400
# saved 20500
# saved 20600
# saved 20700
# saved 20800
# saved 20900
# saved 21000
# saved 21100
# saved 21200
# saved 21300
# saved 21400
# saved 21500
# saved 21600
# saved 21700
# saved 21800
# saved 21900
# saved 22000
# saved 22100
# saved 22200
# saved 22300
# saved 22400
# saved 22500
# saved 22600
# saved 22700
# saved 22800
# saved 22900
# saved 23000
# saved 23100
# saved 23200
# saved 23300
# saved 23400
# saved 23500
# saved 23600
# saved 23700
# saved 23800
# saved 23900
# saved 24000
# saved 24100
# saved 24200
# saved 24300
# saved 24400
# saved 24500
# saved 24600
# saved 24700
# saved 24800
# saved 24900
# saved 25000
# saved 25100
# saved 25200
# saved 25300
# saved 25400
# saved 25500
# saved 25600
# saved 25700
# saved 25800
# saved 25900
# saved 26000
# saved 26100
# saved 26200
# saved 26300
# saved 26400
# saved 26500
# saved 26600
# saved 26700
# saved 26800
# saved 26900
# saved 27000
# saved 27100
# saved 27200
# saved 27300
# saved 27400
# saved 27500
# saved 27600
# saved 27700
# saved 27800
# saved 27900
# saved 28000
# saved 28100
# saved 28200
# saved 28300
# saved 28400
# saved 28500
# saved 28600
# saved 28700
# saved 28800
# saved 28900
# saved 29000
# saved 29100
# saved 29200
# saved 29300
# saved 29400
# saved 29500
# saved 29600
# saved 29700
# saved 29800
# saved 29900
# saved 30000
# saved 30100
# saved 30200
# saved 30300
# saved 30400
# saved 30500
# saved 30600
# saved 30700
# saved 30800
# saved 30900
# saved 31000
# saved 31100
# saved 31200
# saved 31300
# saved 31400
# saved 31500
# saved 31600
# saved 31700
# saved 31800
# saved 31900
# saved 32000
# saved 32100
# saved 32200
# saved 32300
# saved 32400
# saved 32500
# saved 32600
# saved 32700
# saved 32800
# saved 32900
# saved 33000
# saved 33100
# saved 33200
# saved 33300
# saved 33400
# saved 33500
# saved 33600
# saved 33700
# saved 33800
# saved 33900
# saved 34000
# saved 34100
# saved 34200
# saved 34300
# saved 34400
# saved 34500
# saved 34600
# saved 34700
# saved 34800
# saved 34900
# saved 35000
# saved 35100
# saved 35200
# saved 35300
# saved 35400
# saved 35500
# saved 35600
# saved 35700
# saved 35800
# saved 35900
# saved 36000
# saved 36100
# saved 36200
# saved 36300
# saved 36400
# saved 36500
# saved 36600
# saved 36700
# saved 36800
# saved 36900
# saved 37000
# saved 37100
# saved 37200
# saved 37300
# saved 37400
# saved 37500
# saved 37600
# saved 37700
# saved 37800
# saved 37900
# saved 38000
# saved 38100
# saved 38200
# saved 38300
# saved 38400
# saved 38500
# saved 38600
# saved 38700
# saved 38800
# saved 38900
# saved 39000
# saved 39100
# saved 39200
# saved 39300
# saved 39400
# saved 39500
# saved 39600
# saved 39700
# saved 39800
# saved 39900
# saved 40000
# saved 40100
# saved 40200
# saved 40300
# saved 40400
# saved 40500
# saved 40600
# saved 40700
# saved 40800
# saved 40900
# saved 41000
# saved 41100
# saved 41200
# saved 41300
# saved 41400
# saved 41500
# saved 41600
# saved 41700
# saved 41800
# saved 41900
# saved 42000
# saved 42100
# saved 42200
# saved 42300
# saved 42400
# saved 42500
# saved 42600
# saved 42700
# saved 42800
# saved 42900
# saved 43000
# saved 43100
# saved 43200
# saved 43300
# saved 43400
# saved 43500
# saved 43600
# saved 43700
# saved 43800
# saved 43900
# saved 44000
# saved 44100
# saved 44200
# saved 44300
# saved 44400
# saved 44500
# saved 44600
# saved 44700
# saved 44800
# saved 44900
# saved 45000
# saved 45100
# saved 45200
# saved 45300
# saved 45400
# saved 45500
# saved 45600
# saved 45700
# saved 45800
# saved 45900
# saved 46000
# saved 46100
# saved 46200
# saved 46300
# saved 46400
# saved 46500
# saved 46600
# saved 46700
# saved 46800
# saved 46900
# saved 47000
# saved 47100
# saved 47200
# saved 47300
# saved 47400
# saved 47500
# saved 47600
# saved 47700
# saved 47800
# saved 47900
# saved 48000
# saved 48100
# saved 48200
# saved 48300
# saved 48400
# saved 48500
# saved 48600
# saved 48700
# saved 48800
# saved 48900
# saved 49000
# saved 49100
# saved 49200
# saved 49300
# saved 49400
# saved 49500
# saved 49600
# saved 49700
# saved 49800
# saved 49900
# saved 50000
# saved 50100
# saved 50200
# saved 50300
# saved 50400
# saved 50500
# saved 50600
# saved 50700
# saved 50800
# saved 50900
# saved 51000
# saved 51100
# saved 51200
# saved 51300
# saved 51400
# saved 51500
# saved 51600
# saved 51700
# saved 51800
# saved 51900
# saved 52000
# saved 52100
# saved 52200
# saved 52300
# saved 52400
# saved 52500
# saved 52600
# saved 52700
# saved 52800
# saved 52900
# saved 53000
# saved 53100
# saved 53200
# saved 53300
# saved 53400
# saved 53500
# saved 53600
# saved 53700
# saved 53800
# saved 53900
# saved 54000
# saved 54100
# saved 54200
# saved 54300
# saved 54400
# saved 54500
# saved 54600
# saved 54700
# saved 54800
# saved 54900
# saved 55000
# saved 55100
# saved 55200
# saved 55300
# saved 55400
# saved 55500
# saved 55600
# saved 55700
# saved 55800
# saved 55900
# saved 56000
# saved 56100
# saved 56200
# saved 56300
# saved 56400
# saved 56500
# saved 56600
# saved 56700
# saved 56800
# saved 56900
# saved 57000
# saved 57100
# saved 57200
# saved 57300
# saved 57400
# saved 57500
# saved 57600
# saved 57700
# saved 57800
# saved 57900
# saved 58000
# saved 58100
# saved 58200
# saved 58300
# saved 58400
# saved 58500
# saved 58600
# saved 58700
# saved 58800
# saved 58900
# saved 59000
# saved 59100
# saved 59200
# saved 59300
# saved 59400
# saved 59500
# saved 59600
# saved 59700
# saved 59800
# saved 59900
# saved 60000
# saved 60100
# saved 60200
# saved 60300
# saved 60400
# saved 60500
# saved 60600
# saved 60700
# saved 60800
# saved 60900
# saved 61000
# saved 61100
# saved 61200
# saved 61300
# saved 61400
# saved 61500
# saved 61600
# saved 61700
# saved 61800
# saved 61900
# saved 62000
# saved 62100
# saved 62200
# saved 62300
# saved 62400
# saved 62500
# saved 62600
# saved 62700
# saved 62800
# saved 62900
# saved 63000
# saved 63100
# saved 63200
# saved 63300
# saved 63400
# saved 63500
# saved 63600
# saved 63700
# saved 63800
# saved 63900
# saved 64000
# saved 64100
# saved 64200
# saved 64300
# saved 64400
# saved 64500
# saved 64600
# saved 64700
# saved 64800
# saved 64900
# saved 65000
# saved 65100
# saved 65200
# saved 65300
# saved 65400
# saved 65500
# saved 65600
# saved 65700
# saved 65800
# saved 65900
# saved 66000
# saved 66100
# saved 66200
# saved 66300
# saved 66400
# saved 66500
# saved 66600
# saved 66700
# saved 66800
# saved 66900
# saved 67000
# saved 67100
# saved 67200
# saved 67300
# saved 67400
# saved 67500
# saved 67600
# saved 67700
# saved 67800
# saved 67900
# saved 68000
# saved 68100
# saved 68200
# saved 68300
# saved 68400
# saved 68500
# saved 68600
# saved 68700
# saved 68800
# saved 68900
# saved 69000
# saved 69100
# saved 69200
# saved 69300
# saved 69400
# saved 69500
# saved 69600
# saved 69700
# saved 69800
# saved 69900
# saved 70000
# saved 70100
# saved 70200
# saved 70300
# saved 70400
# saved 70500
# saved 70600
# saved 70700
# saved 70800
# saved 70900
# saved 71000
# saved 71100
# saved 71200
# saved 71300
# saved 71400
# saved 71500
# saved 71600
# saved 71700
# saved 71800
# saved 71900
# saved 72000
# saved 72100
# saved 72200
# saved 72300
# saved 72400
# saved 72500
# saved 72600
# saved 72700
# saved 72800
# saved 72900
# saved 73000
# saved 73100
# saved 73200
# saved 73300
# saved 73400
# saved 73500
# saved 73600
# saved 73700
# saved 73800
# saved 73900
# saved 74000
# saved 74100
# saved 74200
# saved 74300
# saved 74400
# saved 74500
# saved 74600
# saved 74700
# saved 74800
# saved 74900
# saved 75000
# saved 75100
# saved 75200
# saved 75300
# saved 75400
# saved 75500
# saved 75600
# saved 75700
# saved 75800
# saved 75900
# saved 76000
# saved 76100
# saved 76200
# saved 76300
# saved 76400
# saved 76500
# saved 76600
# saved 76700
# saved 76800
# saved 76900
# saved 77000
# saved 77100
# saved 77200
# saved 77300
# saved 77400
# saved 77500
# saved 77600
# saved 77700
# saved 77800
# saved 77900
# saved 78000
# saved 78100
# saved 78200
# saved 78300
# saved 78400
# saved 78500
# saved 78600
# saved 78700
# saved 78800
# saved 78900
# saved 79000
# saved 79100
# saved 79200
# saved 79300
# saved 79400
# saved 79500
# saved 79600
# saved 79700
# saved 79800
# saved 79900
# saved 80000
# saved 80100
# saved 80200
# saved 80300
# saved 80400
# saved 80500
# saved 80600
# saved 80700
# saved 80800
# saved 80900
# saved 81000
# saved 81100
# saved 81200
# saved 81300
# saved 81400
# saved 81500
# saved 81600
# saved 81700
# saved 81800
# saved 81900
# saved 82000
# saved 82100
# saved 82200
# saved 82300
# saved 82400
# saved 82500
# saved 82600
# saved 82700
# saved 82800
# saved 82900
# saved 83000
# saved 83100
# saved 83200
# saved 83300
# saved 83400
# saved 83500
# saved 83600
# saved 83700
# saved 83800
# saved 83900
# saved 84000
# saved 84100
# saved 84200
# saved 84300
# saved 84400
# saved 84500
# saved 84600
# saved 84700
# saved 84800
# saved 84900
# saved 85000
# saved 85100
# saved 85200
# saved 85300
# saved 85400
# saved 85500
# saved 85600
# saved 85700
# saved 85800
# saved 85900
# saved 86000
# saved 86100
# saved 86200
# saved 86300
# saved 86400
# saved 86500
# saved 86600
# saved 86700
# saved 86800
# saved 86900
# saved 87000
# saved 87100
# saved 87200
# saved 87300
# saved 87400
# saved 87500
# saved 87600
# saved 87700
# saved 87800
# saved 87900
# saved 88000
# saved 88100
# saved 88200
# saved 88300
# saved 88400
# saved 88500
# saved 88600
# saved 88700
# saved 88800
# saved 88900
# saved 89000
# saved 89100
# saved 89200
# saved 89300
# saved 89400
# saved 89500
# saved 89600
# saved 89700
# saved 89800
# saved 89900
# saved 90000
# saved 90100
# saved 90200
# saved 90300
# saved 90400
# saved 90500
# saved 90600
# saved 90700
# saved 90800
# saved 90900
# saved 91000
# saved 91100
# saved 91200
# saved 91300
# saved 91400
# saved 91500
# saved 91600
# saved 91700
# saved 91800
# saved 91900
# saved 92000
# saved 92100
# saved 92200
# saved 92300
# saved 92400
# saved 92500
# saved 92600
# saved 92700
# saved 92800
# saved 92900
# saved 93000
# saved 93100
# saved 93200
# saved 93300
# saved 93400
# saved 93500
# saved 93600
# saved 93700
# saved 93800
# saved 93900
# saved 94000
# saved 94100
# saved 94200
# saved 94300
# saved 94400
# saved 94500
# saved 94600
# saved 94700
# saved 94800
# saved 94900
# saved 95000
# saved 95100
# saved 95200
# saved 95300
# saved 95400
# saved 95500
# saved 95600
# saved 95700
# saved 95800
# saved 95900
# saved 96000
# saved 96100
# saved 96200
# saved 96300
# saved 96400
# saved 96500
# saved 96600
# saved 96700
# saved 96800
# saved 96900
# saved 97000
# saved 97100
# saved 97200
# saved 97300
# saved 97400
# saved 97500
# saved 97600
# saved 97700
# saved 97800
# saved 97900
# saved 98000
# saved 98100
# saved 98200
# saved 98300
# saved 98400
# saved 98500
# saved 98600
# saved 98700
# saved 98800
# saved 98900
# saved 99000
# saved 99100
# saved 99200
# saved 99300
# saved 99400
# saved 99500
# saved 99600
# saved 99700
# saved 99800
# saved 99900
# saved 100000
# saved 100100
# saved 100200
# saved 100300
# saved 100400
# saved 100500
# saved 100600
# saved 100700
# saved 100800
# saved 100900
# saved 101000
# saved 101100
# saved 101200
# saved 101300
# saved 101400
# saved 101500
# saved 101600
# saved 101700
# saved 101800
# saved 101900
# saved 102000
# saved 102100
# saved 102200
# saved 102300
# saved 102400
# saved 102500
# saved 102600
# saved 102700
# saved 102800
# saved 102900
# saved 103000
# saved 103100
# saved 103200
# saved 103300
# saved 103400
# saved 103500
# saved 103600
# saved 103700
# saved 103800
# saved 103900
# saved 104000
# saved 104100
# saved 104200
# saved 104300
# saved 104400
# saved 104500
# saved 104600
# saved 104700
# saved 104800
# saved 104900
# saved 105000
# saved 105100
# saved 105200
# saved 105300
# saved 105400
# saved 105500
# saved 105600
# saved 105700
# saved 105800
# saved 105900
# saved 106000
# saved 106100
# saved 106200
# saved 106300
# saved 106400
# saved 106500
# saved 106600
# saved 106700
# saved 106800
# saved 106900
# saved 107000
# saved 107100
# saved 107200
# saved 107300
# saved 107400
# saved 107500
# saved 107600
# saved 107700
# saved 107800
# saved 107900
# saved 108000
# saved 108100
# saved 108200
# saved 108300
# saved 108400
# saved 108500
# saved 108600
# saved 108700
# saved 108800
# saved 108900
# saved 109000
# saved 109100
# saved 109200
# saved 109300
# saved 109400
# saved 109500
# saved 109600
# saved 109700
# saved 109800
# saved 109900
# saved 110000
# saved 110100
# saved 110200
# saved 110300
# saved 110400
# saved 110500
# saved 110600
# saved 110700
# saved 110800
# saved 110900
# saved 111000
# saved 111100
# saved 111200
# saved 111300
# saved 111400
# saved 111500
# saved 111600
# saved 111700
# saved 111800
# saved 111900
# saved 112000
# saved 112100
# saved 112200
# saved 112300
# saved 112400
# saved 112500
# saved 112600
# saved 112700
# saved 112800
# saved 112900
# saved 113000
# saved 113100
# saved 113200
# saved 113300
# saved 113400
# saved 113500
# saved 113600
# saved 113700
# saved 113800
# saved 113900
# saved 114000
# saved 114100
# saved 114200
# saved 114300
# saved 114400
# saved 114500
# saved 114600
# saved 114700
# saved 114800
# saved 114900
# saved 115000
# saved 115100
# saved 115200
# saved 115300
# saved 115400
# saved 115500
# saved 115600
# saved 115700
# saved 115800
# saved 115900
# saved 116000
# saved 116100
# saved 116200
# saved 116300
# saved 116400
# saved 116500
# saved 116600
# saved 116700
# saved 116800
# saved 116900
# saved 117000
# saved 117100
# saved 117200
# saved 117300
# saved 117400
# saved 117500
# saved 117600
# saved 117700
# saved 117800
# saved 117900
# saved 118000
# saved 118100
# saved 118200
# saved 118300
# saved 118400
# saved 118500
# saved 118600
# saved 118700
# saved 118800
# saved 118900
# saved 119000
# saved 119100
# saved 119200
# saved 119300
# saved 119400
# saved 119500
# saved 119600
# saved 119700
# saved 119800
# saved 119900
# saved 120000
# saved 120100
# saved 120200
# saved 120300
# saved 120400
# saved 120500
# saved 120600
# saved 120700
# saved 120800
# saved 120900
# saved 121000
# saved 121100
# saved 121200
# saved 121300
# saved 121400
# saved 121500
# saved 121600
# saved 121700
# saved 121800
# saved 121900
# saved 122000
# saved 122100
# saved 122200
# saved 122300
# saved 122400
# saved 122500
# saved 122600
# saved 122700
# saved 122800
# saved 122900
# saved 123000
# saved 123100
# saved 123200
# saved 123300
# saved 123400
# saved 123500
# saved 123600
# saved 123700
# saved 123800
# saved 123900
# saved 124000
# saved 124100
# saved 124200
# saved 124300
# saved 124400
# saved 124500
# saved 124600
# saved 124700
# saved 124800
# saved 124900
# saved 125000
# saved 125100
# saved 125200
# saved 125300
# saved 125400
# saved 125500
# saved 125600
# saved 125700
# saved 125800
# saved 125900
# saved 126000
# saved 126100
# saved 126200
# saved 126300
# saved 126400
# saved 126500
# saved 126600
# saved 126700
# saved 126800
# saved 126900
# saved 127000
# saved 127100
# saved 127200
# saved 127300
# saved 127400
# saved 127500
# saved 127600
# saved 127700
# saved 127800
# saved 127900
# saved 128000
# saved 128100
# saved 128200
# saved 128300
# saved 128400
# saved 128500
# saved 128600
# saved 128700
# saved 128800
# saved 128900
# saved 129000
# saved 129100
# saved 129200
# saved 129300
# saved 129400
# saved 129500
# saved 129600
# saved 129700
# saved 129800
# saved 129900
# saved 130000
# saved 130100
# saved 130200
# saved 130300
# saved 130400
# saved 130500
# saved 130600
# saved 130700
# saved 130800
# saved 130900
# saved 131000
# saved 131100
# saved 131200
# saved 131300
# saved 131400
# saved 131500
# saved 131600
# saved 131700
# saved 131800
# saved 131900
# saved 132000
# saved 132100
# saved 132200
# saved 132300
# saved 132400
# saved 132500
# saved 132600
# saved 132700
# saved 132800
# saved 132900
# saved 133000
# saved 133100
# saved 133200
# saved 133300
# saved 133400
# saved 133500
# saved 133600
# saved 133700
# saved 133800
# saved 133900
# saved 134000
# saved 134100
# saved 134200
# saved 134300
# saved 134400
# saved 134500
# saved 134600
# saved 134700
# saved 134800
# saved 134900
# saved 135000
# saved 135100
# saved 135200
# saved 135300
# saved 135400
# saved 135500
# saved 135600
# saved 135700
# saved 135800
# saved 135900
# saved 136000
# saved 136100
# saved 136200
# saved 136300
# saved 136400
# saved 136500
# saved 136600
# saved 136700
# saved 136800
# saved 136900
# saved 137000
# saved 137100
# saved 137200
# saved 137300
# saved 137400
# saved 137500
# saved 137600
# saved 137700
# saved 137800
# saved 137900
# saved 138000
# saved 138100
# saved 138200
# saved 138300
# saved 138400
# saved 138500
# saved 138600
# saved 138700
# saved 138800
# saved 138900
# saved 139000
# saved 139100
# saved 139200
# saved 139300
# saved 139400
# saved 139500
# saved 139600
# saved 139700
# saved 139800
# saved 139900
# saved 140000
# saved 140100
# saved 140200
# saved 140300
# saved 140400
# saved 140500
# saved 140600
# saved 140700
# saved 140800
# saved 140900
# saved 141000
# saved 141100
# saved 141200
# saved 141300
# saved 141400
# saved 141500
# saved 141600
# saved 141700
# saved 141800
# saved 141900
# saved 142000
# saved 142100
# saved 142200
# saved 142300
# saved 142400
# saved 142500
# saved 142600
# saved 142700
# saved 142800
# saved 142900
# saved 143000
# saved 143100
# saved 143200
# saved 143300
# saved 143400
# saved 143500
# saved 143600
# saved 143700
# saved 143800
# saved 143900
# saved 144000
# saved 144100
# saved 144200
# saved 144300
# saved 144400
# saved 144500
# saved 144600
# saved 144700
# saved 144800
# saved 144900
# saved 145000
# saved 145100
# saved 145200
# saved 145300
# saved 145400
# saved 145500
# saved 145600
# saved 145700
# saved 145800
# saved 145900
# saved 146000
# saved 146100
# saved 146200
# saved 146300
# saved 146400
# saved 146500
# saved 146600
# saved 146700
# saved 146800
# saved 146900
# saved 147000
# saved 147100
# saved 147200
# saved 147300
# saved 147400
# saved 147500
# saved 147600
# saved 147700
# saved 147800
# saved 147900
# saved 148000
# saved 148100
# saved 148200
# saved 148300
# saved 148400
# saved 148500
# saved 148600
# saved 148700
# saved 148800
# saved 148900
# saved 149000
# saved 149100
# saved 149200
# saved 149300
# saved 149400
# saved 149500
# saved 149600
# saved 149700
# saved 149800
# saved 149900
# saved 150000
# saved 150100
# saved 150200
# saved 150300
# saved 150400
# saved 150500
# saved 150600
# saved 150700
# saved 150800
# saved 150900
# saved 151000
# saved 151100
# saved 151200
# saved 151300
# saved 151400
# saved 151500
# saved 151600
# saved 151700
# saved 151800
# saved 151900
# saved 152000
# saved 152100
# saved 152200
# saved 152300
# saved 152400
# saved 152500
# saved 152600
# saved 152700
# saved 152800
# saved 152900
# saved 153000
# saved 153100
# saved 153200
# saved 153300
# saved 153400
# saved 153500
# saved 153600
# saved 153700
# saved 153800
# saved 153900
# saved 154000
# saved 154100
# saved 154200
# saved 154300
# saved 154400
# saved 154500
# saved 154600
# saved 154700
# saved 154800
# saved 154900
# saved 155000
# saved 155100
# saved 155200
# saved 155300
# saved 155400
# saved 155500
# saved 155600
# saved 155700
# saved 155800
# saved 155900
# saved 156000
# saved 156100
# saved 156200
# saved 156300
# saved 156400
# saved 156500
# saved 156600
# saved 156700
# saved 156800
# saved 156900
# saved 157000
# saved 157100
# saved 157200
# saved 157300
# saved 157400
# saved 157500
# saved 157600
# saved 157700
# saved 157800
# saved 157900
# saved 158000
# saved 158100
# saved 158200
# saved 158300
# saved 158400
# saved 158500
# saved 158600
# saved 158700
# saved 158800
# saved 158900
# saved 159000
# saved 159100
# saved 159200
# saved 159300
# saved 159400
# saved 159500
# saved 159600
# saved 159700
# saved 159800
# saved 159900
# saved 160000
# saved 160100
# saved 160200
# saved 160300
# saved 160400
# saved 160500
# saved 160600
# saved 160700
# saved 160800
# saved 160900
# saved 161000
# saved 161100
# saved 161200
# saved 161300
# saved 161400
# saved 161500
# saved 161600
# saved 161700
# saved 161800
# saved 161900
# saved 162000
# saved 162100
# saved 162200
# saved 162300
# saved 162400
# saved 162500
# saved 162600
# saved 162700
# saved 162800
# saved 162900
# saved 163000
# saved 163100
# saved 163200
# saved 163300
# saved 163400
# saved 163500
# saved 163600
# saved 163700
# saved 163800
# saved 163900
# saved 164000
# saved 164100
# saved 164200
# saved 164300
# saved 164400
# saved 164500
# saved 164600
# saved 164700
# saved 164800
# saved 164900
# saved 165000
# saved 165100
# saved 165200
# saved 165300
# saved 165400
# saved 165500
# saved 165600
# saved 165700
# saved 165800
# saved 165900
# saved 166000
# saved 166100
# saved 166200
# saved 166300
# saved 166400
# saved 166500
# saved 166600
# saved 166700
# saved 166800
# saved 166900
# saved 167000
# saved 167100
# saved 167200
# saved 167300
# saved 167400
# saved 167500
# saved 167600
# saved 167700
# saved 167800
# saved 167900
# saved 168000
# saved 168100
# saved 168200
# saved 168300
# saved 168400
# saved 168500
# saved 168600
# saved 168700
# saved 168800
# saved 168900
# saved 169000
# saved 169100
# saved 169200
# saved 169300
# saved 169400
# saved 169500
# saved 169600
# saved 169700
# saved 169800
# saved 169900
# saved 170000
# saved 170100
# saved 170200
# saved 170300
# saved 170400
# saved 170500
# saved 170600
# saved 170700
# saved 170800
# saved 170900
# saved 171000
# saved 171100
# saved 171200
# saved 171300
# saved 171400
# saved 171500
# saved 171600
# saved 171700
# saved 171800
# saved 171900
# saved 172000
# saved 172100
# saved 172200
# saved 172300
# saved 172400
# saved 172500
# saved 172600
# saved 172700
# saved 172800
# saved 172900
# saved 173000
# saved 173100
# saved 173200
# saved 173300
# saved 173400
# saved 173500
# saved 173600
# saved 173700
# saved 173800
# saved 173900
# saved 174000
# saved 174100
# saved 174200
# saved 174300
# saved 174400
# saved 174500
# saved 174600
# saved 174700
# saved 174800
# saved 174900
# saved 175000
# saved 175100
# saved 175200
# saved 175300
# saved 175400
# saved 175500
# saved 175600
# saved 175700
# saved 175800
# saved 175900
# saved 176000
# saved 176100
# saved 176200
# saved 176300
# saved 176400
# saved 176500
# saved 176600
# saved 176700
# saved 176800
# saved 176900
# saved 177000
# saved 177100
# saved 177200
# saved 177300
# saved 177400
# saved 177500
# saved 177600
# saved 177700
# saved 177800
# saved 177900
# saved 178000
# saved 178100
# saved 178200
# saved 178300
# saved 178400
# saved 178500
# saved 178600
# saved 178700
# saved 178800
# saved 178900
# saved 179000
# saved 179100
# saved 179200
# saved 179300
# saved 179400
# saved 179500
# saved 179600
# saved 179700
# saved 179800
# saved 179900
# saved 180000
# saved 180100
# saved 180200
# saved 180300
# saved 180400
# saved 180500
# saved 180600
# saved 180700
# saved 180800
# saved 180900
# saved 181000
# saved 181100
# saved 181200
# saved 181300
# saved 181400
# saved 181500
# saved 181600
# saved 181700
# saved 181800
# saved 181900
# saved 182000
# saved 182100
# saved 182200
# saved 182300
# saved 182400
# saved 182500
# saved 182600
# saved 182700
# saved 182800
# saved 182900
# saved 183000
# saved 183100
# saved 183200
# saved 183300
# saved 183400
# saved 183500
# saved 183600
# saved 183700
# saved 183800
# saved 183900
# saved 184000
# saved 184100
# saved 184200
# saved 184300
# saved 184400
# saved 184500
# saved 184600
# saved 184700
# saved 184800
# saved 184900
# saved 185000
# saved 185100
# saved 185200
# saved 185300
# saved 185400
# saved 185500
# saved 185600
# saved 185700
# saved 185800
# saved 185900
# saved 186000
# saved 186100
# saved 186200
# saved 186300
# saved 186400
# saved 186500
# saved 186600
# saved 186700
# saved 186800
# saved 186900
# saved 187000
# saved 187100
# saved 187200
# saved 187300
# saved 187400
# saved 187500
# saved 187600
# saved 187700
# saved 187800
# saved 187900
# saved 188000
# saved 188100
# saved 188200
# saved 188300
# saved 188400
# saved 188500
# saved 188600
# saved 188700
# saved 188800
# saved 188900
# saved 189000
# saved 189100
# saved 189200
# saved 189300
# saved 189400
# saved 189500
# saved 189600
# saved 189700
# saved 189800
# saved 189900
# saved 190000
# saved 190100
# saved 190200
# saved 190300
# saved 190400
# saved 190500
# saved 190600
# saved 190700
# saved 190800
# saved 190900
# saved 191000
# saved 191100
# saved 191200
# saved 191300
# saved 191400
# saved 191500
# saved 191600
# saved 191700
# saved 191800
# saved 191900
# saved 192000
# saved 192100
# saved 192200
# saved 192300
# saved 192400
# saved 192500
# saved 192600
# saved 192700
# saved 192800
# saved 192900
# saved 193000
# saved 193100
# saved 193200
# saved 193300
# saved 193400
# saved 193500
# saved 193600
# saved 193700
# saved 193800
# saved 193900
# saved 194000
# saved 194100
# saved 194200
# saved 194300
# saved 194400
# saved 194500
# saved 194600
# saved 194700
# saved 194800
# saved 194900
# saved 195000
# saved 195100
# saved 195200
# saved 195300
# saved 195400
# saved 195500
# saved 195600
# saved 195700
# saved 195800
# saved 195900
# saved 196000
# saved 196100
# saved 196200
# saved 196300
# saved 196400
# saved 196500
# saved 196600
# saved 196700
# saved 196800
# saved 196900
# saved 197000
# saved 197100
# saved 197200
# saved 197300
# saved 197400
# saved 197500
# saved 197600
# saved 197700
# saved 197800
# saved 197900
# saved 198000
# saved 198100
# saved 198200
# saved 198300
# saved 198400
# saved 198500
# saved 198600
# saved 198700
# saved 198800
# saved 198900
# saved 199000
# saved 199100
# saved 199200
# saved 199300
# saved 199400
# saved 199500
# saved 199600
# saved 199700
# saved 199800
# saved 199900
# saved 200000
# saved 200100
# saved 200200
# saved 200300
# saved 200400
# saved 200500
# saved 200600
# saved 200700
# saved 200800
# saved 200900
# saved 201000
# saved 201100
# saved 201200
# saved 201300
# saved 201400
# saved 201500
# saved 201600
# saved 201700
# saved 201800
# saved 201900
# saved 202000
# saved 202100
# saved 202200
# saved 202300
# saved 202400
# saved 202500
# saved 202600
# saved 202700
# saved 202800
# saved 202900
# saved 203000
# saved 203100
# saved 203200
# saved 203300
# saved 203400
# saved 203500
# saved 203600
# saved 203700
# saved 203800
# saved 203900
# saved 204000
# saved 204100
# saved 204200
# saved 204300
# saved 204400
# saved 204500
# saved 204600
# saved 204700
# saved 204800
# saved 204900
# saved 205000
# saved 205100
# saved 205200
# saved 205300
# saved 205400
# saved 205500
# saved 205600
# saved 205700
# saved 205800
# saved 205900
# saved 206000
# saved 206100
# saved 206200
# saved 206300
# saved 206400
# saved 206500
# saved 206600
# saved 206700
# saved 206800
# saved 206900
# saved 207000
# saved 207100
# saved 207200
# saved 207300
# saved 207400
# saved 207500
# saved 207600
# saved 207700
# saved 207800
# saved 207900
# saved 208000
# saved 208100
# saved 208200
# saved 208300
# saved 208400
# saved 208500
# saved 208600
# saved 208700
# saved 208800
# saved 208900
# saved 209000
# saved 209100
# saved 209200
# saved 209300
# saved 209400
# saved 209500
# saved 209600
# saved 209700
# saved 209800
# saved 209900
# saved 210000
# saved 210100
# saved 210200
# saved 210300
# saved 210400
# saved 210500
# saved 210600
# saved 210700
# saved 210800
# saved 210900
# saved 211000
# saved 211100
# saved 211200
# saved 211300
# saved 211400
# saved 211500
# saved 211600
# saved 211700
# saved 211800
# saved 211900
# saved 212000
# saved 212100
# saved 212200
# saved 212300
# saved 212400
# saved 212500
# saved 212600
# saved 212700
# saved 212800
# saved 212900
# saved 213000
# saved 213100
# saved 213200
# saved 213300
# saved 213400
# saved 213500
# saved 213600
# saved 213700
# saved 213800
# saved 213900
# saved 214000
# saved 214100
# saved 214200
# saved 214300
# saved 214400
# saved 214500
# saved 214600
# saved 214700
# saved 214800
# saved 214900
# saved 215000
# saved 215100
# saved 215200
# saved 215300
# saved 215400
# saved 215500
# saved 215600
# saved 215700
# saved 215800
# saved 215900
# saved 216000
# saved 216100
# saved 216200
# saved 216300
# saved 216400
# saved 216500
# saved 216600
# saved 216700
# saved 216800
# saved 216900
# saved 217000
# saved 217100
# saved 217200
# saved 217300
# saved 217400
# saved 217500
# saved 217600
# saved 217700
# saved 217800
# saved 217900
# saved 218000
# saved 218100
# saved 218200
# saved 218300
# saved 218400
# saved 218500
# saved 218600
# saved 218700
# saved 218800
# saved 218900
# saved 219000
# saved 219100
# saved 219200
# saved 219300
# saved 219400
# saved 219500
# saved 219600
# saved 219700
# saved 219800
# saved 219900
# saved 220000
# saved 220064
# done, total=220064

# %%
def stream_all_closed_events_to_file(
    limit=100,
    sleep_sec=0.3,
    out_file=None
):
    offset = 0
    total = 0

    with open(out_file, "w", encoding="utf-8") as f:
        while True:
            params = {
                "closed": True,
                "limit": limit,
                "offset": offset,
            }

            try:
                batch = get_events(querystring_params=params)
            except Exception as e:
                print("retry...")
                time.sleep(2)
                continue

            if not batch:
                break

            for event in batch:
                f.write(json.dumps(event) + "\n")
                total += 1

            print(f"saved {total}")

            if len(batch) < limit:
                break

            offset += limit
            time.sleep(sleep_sec)

    print(f"done, total={total}")

# %%
stream_all_closed_events_to_file(limit=100, sleep_sec=0.3, out_file="all_closed_events.jsonl")
# Out:
# saved 100
# saved 200
# saved 300
# saved 400
# saved 500
# saved 600
# saved 700
# saved 800
# saved 900
# saved 1000
# saved 1100
# saved 1200
# saved 1300
# saved 1400
# saved 1500
# saved 1600
# saved 1700
# saved 1800
# saved 1900
# saved 2000
# saved 2100
# saved 2200
# saved 2300
# saved 2400
# saved 2500
# saved 2600
# saved 2700
# saved 2800
# saved 2900
# saved 3000
# saved 3100
# saved 3200
# saved 3300
# saved 3400
# saved 3500
# saved 3600
# saved 3700
# saved 3800
# saved 3900
# saved 4000
# saved 4100
# saved 4200
# saved 4300
# saved 4400
# saved 4500
# saved 4600
# saved 4700
# saved 4800
# saved 4900
# saved 5000
# saved 5100
# saved 5200
# saved 5300
# saved 5400
# saved 5500
# saved 5600
# saved 5700
# saved 5800
# saved 5900
# saved 6000
# saved 6100
# saved 6200
# saved 6300
# saved 6400
# saved 6500
# saved 6600
# saved 6700
# saved 6800
# saved 6900
# saved 7000
# saved 7100
# saved 7200
# saved 7300
# saved 7400
# saved 7500
# saved 7600
# saved 7700
# saved 7800
# saved 7900
# saved 8000
# saved 8100
# saved 8200
# saved 8300
# saved 8400
# saved 8500
# saved 8600
# saved 8700
# saved 8800
# saved 8900
# saved 9000
# saved 9100
# saved 9200
# saved 9300
# saved 9400
# saved 9500
# saved 9600
# saved 9700
# saved 9800
# saved 9900
# saved 10000
# saved 10100
# saved 10200
# saved 10300
# saved 10400
# saved 10500
# saved 10600
# saved 10700
# saved 10800
# saved 10900
# saved 11000
# saved 11100
# saved 11200
# saved 11300
# saved 11400
# saved 11500
# saved 11600
# saved 11700
# saved 11800
# saved 11900
# saved 12000
# saved 12100
# saved 12200
# saved 12300
# saved 12400
# saved 12500
# saved 12600
# saved 12700
# saved 12800
# saved 12900
# saved 13000
# saved 13100
# saved 13200
# saved 13300
# saved 13400
# saved 13500
# saved 13600
# saved 13700
# saved 13800
# saved 13900
# saved 14000
# saved 14100
# saved 14200
# saved 14300
# saved 14400
# saved 14500
# saved 14600
# saved 14700
# saved 14800
# saved 14900
# saved 15000
# saved 15100
# saved 15200
# saved 15300
# saved 15400
# saved 15500
# saved 15600
# saved 15700
# saved 15800
# saved 15900
# saved 16000
# saved 16100
# saved 16200
# saved 16300
# saved 16400
# saved 16500
# saved 16600
# saved 16700
# saved 16800
# saved 16900
# saved 17000
# saved 17100
# saved 17200
# saved 17300
# saved 17400
# saved 17500
# saved 17600
# saved 17700
# saved 17800
# saved 17900
# saved 18000
# saved 18100
# saved 18200
# saved 18300
# saved 18400
# saved 18500
# saved 18600
# saved 18700
# saved 18800
# saved 18900
# saved 19000
# saved 19100
# saved 19200
# saved 19300
# saved 19400
# saved 19500
# saved 19600
# saved 19700
# saved 19800
# saved 19900
# saved 20000
# saved 20100
# saved 20200
# saved 20300
# saved 20400
# saved 20500
# saved 20600
# saved 20700
# saved 20800
# saved 20900
# saved 21000
# saved 21100
# saved 21200
# saved 21300
# saved 21400
# saved 21500
# saved 21600
# saved 21700
# saved 21800
# saved 21900
# saved 22000
# saved 22100
# saved 22200
# saved 22300
# saved 22400
# saved 22500
# saved 22600
# saved 22700
# saved 22800
# saved 22900
# saved 23000
# saved 23100
# saved 23200
# saved 23300
# saved 23400
# saved 23500
# saved 23600
# saved 23700
# saved 23800
# saved 23900
# saved 24000
# saved 24100
# saved 24200
# saved 24300
# saved 24400
# saved 24500
# saved 24600
# saved 24700
# saved 24800
# saved 24900
# saved 25000
# saved 25100
# saved 25200
# saved 25300
# saved 25400
# saved 25500
# saved 25600
# saved 25700
# saved 25800
# saved 25900
# saved 26000
# saved 26100
# saved 26200
# saved 26300
# saved 26400
# saved 26500
# saved 26600
# saved 26700
# saved 26800
# saved 26900
# saved 27000
# saved 27100
# saved 27200
# saved 27300
# saved 27400
# saved 27500
# saved 27600
# saved 27700
# saved 27800
# saved 27900
# saved 28000
# saved 28100
# saved 28200
# saved 28300
# saved 28400
# saved 28500
# saved 28600
# saved 28700
# saved 28800
# saved 28900
# saved 29000
# saved 29100
# saved 29200
# saved 29300
# saved 29400
# saved 29500
# saved 29600
# saved 29700
# saved 29800
# saved 29900
# saved 30000
# saved 30100
# saved 30200
# saved 30300
# saved 30400
# saved 30500
# saved 30600
# saved 30700
# saved 30800
# saved 30900
# saved 31000
# saved 31100
# saved 31200
# saved 31300
# saved 31400
# saved 31500
# saved 31600
# saved 31700
# saved 31800
# saved 31900
# saved 32000
# saved 32100
# saved 32200
# saved 32300
# saved 32400
# saved 32500
# saved 32600
# saved 32700
# saved 32800
# saved 32900
# saved 33000
# saved 33100
# saved 33200
# saved 33300
# saved 33400
# saved 33500
# saved 33600
# saved 33700
# saved 33800
# saved 33900
# saved 34000
# saved 34100
# saved 34200
# saved 34300
# saved 34400
# saved 34500
# saved 34600
# saved 34700
# saved 34800
# saved 34900
# saved 35000
# saved 35100
# saved 35200
# saved 35300
# saved 35400
# saved 35500
# saved 35600
# saved 35700
# saved 35800
# saved 35900
# saved 36000
# saved 36100
# saved 36200
# saved 36300
# saved 36400
# saved 36500
# saved 36600
# saved 36700
# saved 36800
# saved 36900
# saved 37000
# saved 37100
# saved 37200
# saved 37300
# saved 37400
# saved 37500
# saved 37600
# saved 37700
# saved 37800
# saved 37900
# saved 38000
# saved 38100
# saved 38200
# saved 38300
# saved 38400
# saved 38500
# saved 38600
# saved 38700
# saved 38800
# saved 38900
# saved 39000
# saved 39100
# saved 39200
# saved 39300
# saved 39400
# saved 39500
# saved 39600
# saved 39700
# saved 39800
# saved 39900
# saved 40000
# saved 40100
# saved 40200
# saved 40300
# saved 40400
# saved 40500
# saved 40600
# saved 40700
# saved 40800
# saved 40900
# saved 41000
# saved 41100
# saved 41200
# saved 41300
# saved 41400
# saved 41500
# saved 41600
# saved 41700
# saved 41800
# saved 41900
# saved 42000
# saved 42100
# saved 42200
# saved 42300
# saved 42400
# saved 42500
# saved 42600
# saved 42700
# saved 42800
# saved 42900
# saved 43000
# saved 43100
# saved 43200
# saved 43300
# saved 43400
# saved 43500
# saved 43600
# saved 43700
# saved 43800
# saved 43900
# saved 44000
# saved 44100
# saved 44200
# saved 44300
# saved 44400
# saved 44500
# saved 44600
# saved 44700
# saved 44800
# saved 44900
# saved 45000
# saved 45100
# saved 45200
# saved 45300
# saved 45400
# saved 45500
# saved 45600
# saved 45700
# saved 45800
# saved 45900
# saved 46000
# saved 46100
# saved 46200
# saved 46300
# saved 46400
# saved 46500
# saved 46600
# saved 46700
# saved 46800
# saved 46900
# saved 47000
# saved 47100
# saved 47200
# saved 47300
# saved 47400
# saved 47500
# saved 47600
# saved 47700
# saved 47800
# saved 47900
# saved 48000
# saved 48100
# saved 48200
# saved 48300
# saved 48400
# saved 48500
# saved 48600
# saved 48700
# saved 48800
# saved 48900
# saved 49000
# saved 49100
# saved 49200
# saved 49300
# saved 49400
# saved 49500
# saved 49600
# saved 49700
# saved 49800
# saved 49900
# saved 50000
# saved 50100
# saved 50200
# saved 50300
# saved 50400
# saved 50500
# saved 50600
# saved 50700
# saved 50800
# saved 50900
# saved 51000
# saved 51100
# saved 51200
# saved 51300
# saved 51400
# saved 51500
# saved 51600
# saved 51700
# saved 51800
# saved 51900
# saved 52000
# saved 52100
# saved 52200
# saved 52300
# saved 52400
# saved 52500
# saved 52600
# saved 52700
# saved 52800
# saved 52900
# saved 53000
# saved 53100
# saved 53200
# saved 53300
# saved 53400
# saved 53500
# saved 53600
# saved 53700
# saved 53800
# saved 53900
# saved 54000
# saved 54100
# saved 54200
# saved 54300
# saved 54400
# saved 54500
# saved 54600
# saved 54700
# saved 54800
# saved 54900
# saved 55000
# saved 55100
# saved 55200
# saved 55300
# saved 55400
# saved 55500
# saved 55600
# saved 55700
# saved 55800
# saved 55900
# saved 56000
# saved 56100
# saved 56200
# saved 56300
# saved 56400
# saved 56500
# saved 56600
# saved 56700
# saved 56800
# saved 56900
# saved 57000
# saved 57100
# saved 57200
# saved 57300
# saved 57400
# saved 57500
# saved 57600
# saved 57700
# saved 57800
# saved 57900
# saved 58000
# saved 58100
# saved 58200
# saved 58300
# saved 58400
# saved 58500
# saved 58600
# saved 58700
# saved 58800
# saved 58900
# saved 59000
# saved 59100
# saved 59200
# saved 59300
# saved 59400
# saved 59500
# saved 59600
# saved 59700
# saved 59800
# saved 59900
# saved 60000
# saved 60100
# saved 60200
# saved 60300
# saved 60400
# saved 60500
# saved 60600
# saved 60700
# saved 60800
# saved 60900
# saved 61000
# saved 61100
# saved 61200
# saved 61300
# saved 61400
# saved 61500
# saved 61600
# saved 61700
# saved 61800
# saved 61900
# saved 62000
# saved 62100
# saved 62200
# saved 62300
# saved 62400
# saved 62500
# saved 62600
# saved 62700
# saved 62800
# saved 62900
# saved 63000
# saved 63100
# saved 63200
# saved 63300
# saved 63400
# saved 63500
# saved 63600
# saved 63700
# saved 63800
# saved 63900
# saved 64000
# saved 64100
# saved 64200
# saved 64300
# saved 64400
# saved 64500
# saved 64600
# saved 64700
# saved 64800
# saved 64900
# saved 65000
# saved 65100
# saved 65200
# saved 65300
# saved 65400
# saved 65500
# saved 65600
# saved 65700
# saved 65800
# saved 65900
# saved 66000
# saved 66100
# saved 66200
# saved 66300
# saved 66400
# saved 66500
# saved 66600
# saved 66700
# saved 66800
# saved 66900
# saved 67000
# saved 67100
# saved 67200
# saved 67300
# saved 67400
# saved 67500
# saved 67600
# saved 67700
# saved 67800
# saved 67900
# saved 68000
# saved 68100
# saved 68200
# saved 68300
# saved 68400
# saved 68500
# saved 68600
# saved 68700
# saved 68800
# saved 68900
# saved 69000
# saved 69100
# saved 69200
# saved 69300
# saved 69400
# saved 69500
# saved 69600
# saved 69700
# saved 69800
# saved 69900
# saved 70000
# saved 70100
# saved 70200
# saved 70300
# saved 70400
# saved 70500
# saved 70600
# saved 70700
# saved 70800
# saved 70900
# saved 71000
# saved 71100
# saved 71200
# saved 71300
# saved 71400
# saved 71500
# saved 71600
# saved 71700
# saved 71800
# saved 71900
# saved 72000
# saved 72100
# saved 72200
# saved 72300
# saved 72400
# saved 72500
# saved 72600
# saved 72700
# saved 72800
# saved 72900
# saved 73000
# saved 73100
# saved 73200
# saved 73300
# saved 73400
# saved 73500
# saved 73600
# saved 73700
# saved 73800
# saved 73900
# saved 74000
# saved 74100
# saved 74200
# saved 74300
# saved 74400
# saved 74500
# saved 74600
# saved 74700
# saved 74800
# saved 74900
# saved 75000
# saved 75100
# saved 75200
# saved 75300
# saved 75400
# saved 75500
# saved 75600
# saved 75700
# saved 75800
# saved 75900
# saved 76000
# saved 76100
# saved 76200
# saved 76300
# saved 76400
# saved 76500
# saved 76600
# saved 76700
# saved 76800
# saved 76900
# saved 77000
# saved 77100
# saved 77200
# saved 77300
# saved 77400
# saved 77500
# saved 77600
# saved 77700
# saved 77800
# saved 77900
# saved 78000
# saved 78100
# saved 78200
# saved 78300
# saved 78400
# saved 78500
# saved 78600
# saved 78700
# saved 78800
# saved 78900
# saved 79000
# saved 79100
# saved 79200
# saved 79300
# saved 79400
# saved 79500
# saved 79600
# saved 79700
# saved 79800
# saved 79900
# saved 80000
# saved 80100
# saved 80200
# saved 80300
# saved 80400
# saved 80500
# saved 80600
# saved 80700
# saved 80800
# saved 80900
# saved 81000
# saved 81100
# saved 81200
# saved 81300
# saved 81400
# saved 81500
# saved 81600
# saved 81700
# saved 81800
# saved 81900
# saved 82000
# saved 82100
# saved 82200
# saved 82300
# saved 82400
# saved 82500
# saved 82600
# saved 82700
# saved 82800
# saved 82900
# saved 83000
# saved 83100
# saved 83200
# saved 83300
# saved 83400
# saved 83500
# saved 83600
# saved 83700
# saved 83800
# saved 83900
# saved 84000
# saved 84100
# saved 84200
# saved 84300
# saved 84400
# saved 84500
# saved 84600
# saved 84700
# saved 84800
# saved 84900
# saved 85000
# saved 85100
# saved 85200
# saved 85300
# saved 85400
# saved 85500
# saved 85600
# saved 85700
# saved 85800
# saved 85900
# saved 86000
# saved 86100
# saved 86200
# saved 86300
# saved 86400
# saved 86500
# saved 86600
# saved 86700
# saved 86800
# saved 86900
# saved 87000
# saved 87100
# saved 87200
# saved 87300
# saved 87400
# saved 87500
# saved 87600
# saved 87700
# saved 87800
# saved 87900
# saved 88000
# saved 88100
# saved 88200
# saved 88300
# saved 88400
# saved 88500
# saved 88600
# saved 88700
# saved 88800
# saved 88900
# saved 89000
# saved 89100
# saved 89200
# saved 89300
# saved 89400
# saved 89500
# saved 89600
# saved 89700
# saved 89800
# saved 89900
# saved 90000
# saved 90100
# saved 90200
# saved 90300
# saved 90400
# saved 90500
# saved 90600
# saved 90700
# saved 90800
# saved 90900
# saved 91000
# saved 91100
# saved 91200
# saved 91300
# saved 91400
# saved 91500
# saved 91600
# saved 91700
# saved 91800
# saved 91900
# saved 92000
# saved 92100
# saved 92200
# saved 92300
# saved 92400
# saved 92500
# saved 92600
# saved 92700
# saved 92800
# saved 92900
# saved 93000
# saved 93100
# saved 93200
# saved 93300
# saved 93400
# saved 93500
# saved 93600
# saved 93700
# saved 93800
# saved 93900
# saved 94000
# saved 94100
# saved 94200
# saved 94300
# saved 94400
# saved 94500
# saved 94600
# saved 94700
# saved 94800
# saved 94900
# saved 95000
# saved 95100
# saved 95200
# saved 95300
# saved 95400
# saved 95500
# saved 95600
# saved 95700
# saved 95800
# saved 95900
# saved 96000
# saved 96100
# saved 96200
# saved 96300
# saved 96400
# saved 96500
# saved 96600
# saved 96700
# saved 96800
# saved 96900
# saved 97000
# saved 97100
# saved 97200
# saved 97300
# saved 97400
# saved 97500
# saved 97600
# saved 97700
# saved 97800
# saved 97900
# saved 98000
# saved 98100
# saved 98200
# saved 98300
# saved 98400
# saved 98500
# saved 98600
# saved 98700
# saved 98800
# saved 98900
# saved 99000
# saved 99100
# saved 99200
# saved 99300
# saved 99400
# saved 99500
# saved 99600
# saved 99700
# saved 99800
# saved 99900
# saved 99901
# done, total=99901

# %%
def get_current_events(limit=4) -> "list":
        return get_events(
            querystring_params={
                "active": True,
                "closed": False,
                "archived": False,
                "limit": limit,
            }
        )

# %%
def get_market(market_id: int) -> dict:
        url = gamma_markets_endpoint + "/" + str(market_id)
        print(url)
        response = httpx.get(url)
        return response.json()
